# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/learning-agency-lab-automated-essay-scoring-2/sample_submission.csv
# /kaggle/input/learning-agency-lab-automated-essay-scoring-2/train.csv
# /kaggle/input/learning-agency-lab-automated-essay-scoring-2/test.csv

# %%
import ast
import copy
import gc
import itertools
import joblib
import json
import math
import matplotlib.pyplot as plt
import multiprocessing
import numpy as np
import os
import pandas as pd
import pickle
import random
import re
import scipy as sp
import string
import sys
import time
import warnings
import wandb
from sklearn.metrics import cohen_kappa_score
from sklearn.model_selection import StratifiedKFold, GroupKFold, KFold
import torch
import torch.nn as nn
from torch.nn import Parameter
import torch.nn.functional as F
from torch.optim import Adam, SGD, AdamW
from torch.utils.data import DataLoader, Dataset
from tqdm.auto import tqdm
# ======= OPTIONS =========
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Current device is: {device}")
warnings.filterwarnings("ignore")
# !mkdir output
# Out:
# Current device is: cuda

# %%
import tokenizers
import transformers
from transformers import AutoTokenizer, AutoModel, AutoConfig
from tokenizers import AddedToken
from transformers import get_linear_schedule_with_warmup, get_cosine_schedule_with_warmup
# %env TOKENIZERS_PARALLELISM=true
#print(f"tokenizers.__version__: {tokenizers.__version__}")
#print(f"transformers.__version__: {transformers.__version_}")
# Out:
# env: TOKENIZERS_PARALLELISM=true

# %%
class config:
    APEX = True # Automatic Precision Enabled
    BATCH_SCHEDULER = True
    BATCH_SIZE_TRAIN = 4
    BATCH_SIZE_VALID = 4
    BETAS = (0.9, 0.999)
    DEBUG = False
    DECODER_LR = 2e-5
    ENCODER_LR = 2e-5
    EPOCHS = 2
    EPS = 1e-6
    layerwise_learning_rate_decay= 0.9
    FOLDS = 5
    GRADIENT_ACCUMULATION_STEPS = 1
    GRADIENT_CHECKPOINTING = True
    MAX_GRAD_NORM=1000
    MAX_LEN = 512
    MIN_LR = 2e-5
    #MODEL = "google/bigbird-roberta-base"
    MODEL= "Microsoft/deberta-v3-small"
    NUM_CYCLES = 0.5
    NUM_CLASSES = 6
    NUM_WARMUP_STEPS = 0
    NUM_WORKERS = 0 #multiprocessing.cpu_count()
    PRINT_FREQ = 20
    SCHEDULER = 'cosine' # ['linear', 'cosine']
    SEED = 20
    TRAIN = True
    TRAIN_FOLDS = [0, 1, 2, 3, 4]
    WEIGHT_DECAY = 0.01
    #num_hidden_layers=13
class paths:
    OUTPUT_DIR = "/kaggle/working/output"
    TEST_CSV = "/kaggle/input/learning-agency-lab-automated-essay-scoring-2/test.csv"
    TRAIN_CSV = "/kaggle/input/learning-agency-lab-automated-essay-scoring-2/train.csv"
if config.DEBUG:
    config.EPOCHS = 2
    config.TRAIN_FOLDS = [0]

# %%
def get_optimizer_grouped_parameters(
    model,
    learning_rate, weight_decay, 
    layerwise_learning_rate_decay
):
    no_decay = ["bias", "LayerNorm.weight"]
    # initialize lr for task specific layer
    optimizer_grouped_parameters = [
        {
            "params": [p for n, p in model.named_parameters() if "classifier" in n or "pooler" in n],
            "weight_decay": 0.0,
            "lr": learning_rate,
        },
    ]
    # initialize lrs for every layer
    num_layers = model.config.num_hidden_layers
    layers =  [model.model.embeddings.word_embeddings] + list(model.model.encoder.layer)
    layers.reverse()
    lr = learning_rate
    for layer in layers:
        lr *= layerwise_learning_rate_decay
        optimizer_grouped_parameters += [
            {
                "params": [p for n, p in layer.named_parameters() if not any(nd in n for nd in no_decay)],
                "weight_decay": weight_decay,
                "lr": lr,
            },
            {
                "params": [p for n, p in layer.named_parameters() if any(nd in n for nd in no_decay)],
                "weight_decay": 0.0,
                "lr": lr,
            },
        ]
    return optimizer_grouped_parameters
"""
def get_optimizer_params(model, encoder_lr, decoder_lr, weight_decay=0.0):
    param_optimizer = list(model.named_parameters())
    no_decay = ["bias", "LayerNorm.bias", "LayerNorm.weight"]
    optimizer_parameters = [
        {'params': [p for n, p in model.model.named_parameters() if not any(nd in n for nd in no_decay)],
         'lr': encoder_lr, 'weight_decay': weight_decay},
        {'params': [p for n, p in model.model.named_parameters() if any(nd in n for nd in no_decay)],
         'lr': encoder_lr, 'weight_decay': 0.0},
        {'params': [p for n, p in model.named_parameters() if "model" not in n],
         'lr': decoder_lr, 'weight_decay': 0.0}
    ]
    return optimizer_parameters
    """
def get_logger(filename=paths.OUTPUT_DIR):
    from logging import getLogger, INFO, StreamHandler, FileHandler, Formatter
    logger = getLogger(__name__)
    logger.setLevel(INFO)
    handler1 = StreamHandler()
    handler1.setFormatter(Formatter("%(message)s"))
    handler2 = FileHandler(filename=f"{filename}.log")
    handler2.setFormatter(Formatter("%(message)s"))
    logger.addHandler(handler1)
    logger.addHandler(handler2)
    return logger
def get_scheduler(cfg, optimizer, num_train_steps):
    if cfg.SCHEDULER == 'linear':
        scheduler = get_linear_schedule_with_warmup(
            optimizer, num_warmup_steps=cfg.NUM_WARMUP_STEPS,
            num_training_steps=num_train_steps
        )
    elif cfg.SCHEDULER == 'cosine':
        scheduler = get_cosine_schedule_with_warmup(
            optimizer, num_warmup_steps=cfg.NUM_WARMUP_STEPS,
            num_training_steps=num_train_steps, num_cycles=cfg.NUM_CYCLES
        )
    return scheduler
def get_score(y_true, y_pred):
    score = cohen_kappa_score(y_true, y_pred, weights='quadratic')
    return score
def seed_everything(seed=20):
    """Seed everything to ensure reproducibility"""
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
def sep():
    print("-"*100)
LOGGER = get_logger()
seed_everything(seed=config.SEED)

# %%
train_df = pd.read_csv(paths.TRAIN_CSV, sep=',')
train_df["score"] = train_df["score"] - 1
test_df = pd.read_csv(paths.TEST_CSV, sep=',')
print(f"Train dataframe has shape: {train_df.shape}"), sep()
print(f"Test dataframe has shape: {test_df.shape}"), sep()
display(train_df.head())
display(test_df.head())
# Out:
# Train dataframe has shape: (17307, 3)
# ----------------------------------------------------------------------------------------------------
# Test dataframe has shape: (3, 2)
# ----------------------------------------------------------------------------------------------------
#   essay_id                                          full_text  score
# 0  000d118  Many people have car where they live. The thin...      2
# 1  000fe60  I am a scientist at NASA that is discussing th...      2
# 2  001ab80  People always wish they had the same technolog...      3
# 3  001bdc0  We all heard about Venus, the planet without a...      3
# 4  002ba53  Dear, State Senator\n\nThis is a letter to arg...      2
#   essay_id                                          full_text
# 0  000d118  Many people have car where they live. The thin...
# 1  000fe60  I am a scientist at NASA that is discussing th...
# 2  001ab80  People always wish they had the same technolog...

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
train_df["fold"] = -1
X = train_df["full_text"]
y = train_df["score"]
skf = StratifiedKFold(n_splits=config.FOLDS)
for i, (train_index, val_index) in enumerate(skf.split(X, y)):
    train_df.loc[val_index, "fold"] = i
print(train_df["fold"].value_counts())
# Out:
# fold
# 0    3462
# 1    3462
# 2    3461
# 3    3461
# 4    3461
# Name: count, dtype: int64

# %%
tokenizer = AutoTokenizer.from_pretrained(config.MODEL)
tokenizer.save_pretrained(paths.OUTPUT_DIR + '/tokenizer/')
#tokenizer.add_tokens([AddedToken("\n", normalized=False)])
#tokenizer.add_tokens([AddedToken(" "*2, normalized=False)])
print(tokenizer)
# Out:
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/578 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# DebertaV2TokenizerFast(name_or_path='Microsoft/deberta-v3-small', vocab_size=128000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '[CLS]', 'eos_token': '[SEP]', 'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	3: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# 	128000: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
def prepare_input(cfg, text, tokenizer):
    """
    This function tokenizes the input text with the configured padding and truncation. Then,
    returns the input dictionary, which contains the following keys: "input_ids",
    "token_type_ids" and "attention_mask". Each value is a torch.tensor.
    :param cfg: configuration class with a TOKENIZER attribute.
    :param text: a numpy array where each value is a text as string.
    :return inputs: python dictionary where values are torch tensors.
    """
    inputs = tokenizer.encode_plus(
        text,
        return_tensors=None,
        add_special_tokens=True,
        max_length=cfg.MAX_LEN,
        padding='max_length', # TODO: check padding to max sequence in batch
        truncation=True
    )
    for k, v in inputs.items():
        inputs[k] = torch.tensor(v, dtype=torch.long) # TODO: check dtypes
    return inputs
def collate(inputs):
    """
    It truncates the inputs to the maximum sequence length in the batch.
    """
    mask_len = int(inputs["attention_mask"].sum(axis=1).max()) # Get batch's max sequence length
    for k, v in inputs.items():
        inputs[k] = inputs[k][:,:mask_len]
    return inputs
class CustomDataset(Dataset):
    def __init__(self, cfg, df, tokenizer):
        self.cfg = cfg
        self.texts = df['full_text'].values
        self.labels = df['score'].values
        self.tokenizer = tokenizer
        self.essay_ids = df['essay_id'].values
    def __len__(self):
        return len(self.texts)
    def __getitem__(self, item):
        output = {}
        output["inputs"] = prepare_input(self.cfg, self.texts[item], self.tokenizer)
        output["labels"] = torch.tensor(self.labels[item], dtype=torch.long) # TODO: check dtypes
        output["essay_ids"] = self.essay_ids[item]
        return output

# %%
"""
class MeanPooling(nn.Module):
    def __init__(self):
        super(MeanPooling, self).__init__()
    def forward(self, last_hidden_state, attention_mask):
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        sum_mask = input_mask_expanded.sum(1)
        sum_mask = torch.clamp(sum_mask, min=1e-9)
        mean_embeddings = sum_embeddings / sum_mask
        return mean_embeddings
class CustomModel(nn.Module):
    def __init__(self, cfg, config_path=None, pretrained=False):
        super().__init__()
        self.cfg = cfg
        # Load config by inferencing it from the model name.
        if config_path is None:
            self.config = AutoConfig.from_pretrained(cfg.MODEL, output_hidden_states=True)
            self.config.hidden_dropout = 0.
            self.config.hidden_dropout_prob = 0.
            self.config.attention_dropout = 0.
            self.config.attention_probs_dropout_prob = 0.
        # Load config from a file.
        else:
            self.config = torch.load(config_path)
        if pretrained:
            self.model = AutoModel.from_pretrained(cfg.MODEL, config=self.config)
        else:
            self.model = AutoModel(self.config)
        if self.cfg.GRADIENT_CHECKPOINTING:
            self.model.gradient_checkpointing_enable()
        # Add MeanPooling and Linear head at the end to transform the Model into a RegressionModel
        self.pool = MeanPooling()
        self.fc = nn.Linear(self.config.hidden_size, config.NUM_CLASSES)
        self._init_weights(self.fc)
    def _init_weights(self, module):
        
        #This method initializes weights for different types of layers. The type of layers
        #supported are nn.Linear, nn.Embedding and nn.LayerNorm.
        
        
  
     
        from transformers import logging
        logging.set_verbosity_warning()
        logging.set_verbosity_error()
        from transformers import AutoConfig
        from transformers import AutoModelForSequenceClassification
        
        #_model_type = 'deberta'
        _pretrained_model = 'microsoft/deberta-v3-small'
        config = AutoConfig.from_pretrained(_pretrained_model)
        #model = AutoModelForSequenceClassification.from_pretrained
        reinit_layers = 2
        deberta_model = transformers.TFAutoModel.from_pretrained(_pretrained_model, config=self.config)
        #_model_type = 'google/bigbird-roberta-base'
        if reinit_layers > 0:
            print(f'Reinitializing Last {reinit_layers} Layers ...')
            #encoder_temp = getattr(self.model, _model_type)
            for encoder_block in deberta_model.deberta.encoder.layer[-reinit_layers:]:
            #         print(f'{encoder_block}')
                for layer in encoder_block.submodules:
            #for layer in model.deberta.encoder.layer[-reinit_layers:]:
                #for module in layer.modules():
                    if isinstance(module, nn.Linear):
                        module.weight.data.normal_(mean=0.0, std=config.initializer_range)
                        if module.bias is not None:
                            module.bias.data.zero_()
                    elif isinstance(module, nn.Embedding):
                        module.weight.data.normal_(mean=0.0, std=config.initializer_range)
                        if module.padding_idx is not None:
                            module.weight.data[module.padding_idx].zero_()
                    elif isinstance(module, nn.LayerNorm):
                        module.bias.data.zero_()
                        module.weight.data.fill_(1.0)
    def feature(self, inputs):
        
        
        #This method makes a forward pass through the model, get the last hidden state (embedding)
        #and pass it through the MeanPooling layer.
        
        
        
        outputs = self.model(**inputs)
        last_hidden_states = outputs[0]
        feature = self.pool(last_hidden_states, inputs['attention_mask'])
        return feature
    def forward(self, inputs):
        
        
        #This method makes a forward pass through the model, the MeanPooling layer and finally
        #then through the Linear layer to get a regression value.
        
        
        feature = self.feature(inputs)
        output = self.fc(feature)
        return output
        """
# Out:
# "\nclass MeanPooling(nn.Module):\n    def __init__(self):\n        super(MeanPooling, self).__init__()\n    def forward(self, last_hidden_state, attention_mask):\n        input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()\n        sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)\n        sum_mask = input_mask_expanded.sum(1)\n        sum_mask = torch.clamp(sum_mask, min=1e-9)\n        mean_embeddings = sum_embeddings / sum_mask\n        return mean_embeddings\nclass CustomModel(nn.Module):\n    def __init__(self, cfg, config_path=None, pretrained=False):\n        super().__init__()\n        self.cfg = cfg\n        # Load config by inferencing it from the model name.\n        if config_path is None:\n            self.config = AutoConfig.from_pretrained(cfg.MODEL, output_hidden_states=True)\n            self.config.hidden_dropout = 0.\n            self.config.hidden_dropout_prob = 0.\n            self.config.attention_dropout = 0.\n            self.config.attention_probs_dropout_prob = 0.\n        # Load config from a file.\n        else:\n            self.config = torch.load(config_path)\n        if pretrained:\n            self.model = AutoModel.from_pretrained(cfg.MODEL, config=self.config)\n        else:\n            self.model = AutoModel(self.config)\n        if self.cfg.GRADIENT_CHECKPOINTING:\n            self.model.gradient_checkpointing_enable()\n        # Add MeanPooling and Linear head at the end to transform the Model into a RegressionModel\n        self.pool = MeanPooling()\n        self.fc = nn.Linear(self.config.hidden_size, config.NUM_CLASSES)\n        self._init_weights(self.fc)\n    def _init_weights(self, module):\n        \n        #This method initializes weights for different types of layers. The type of layers\n        #supported are nn.Linear, nn.Embedding and nn.LayerNorm.\n        \n        \n  \n     \n        from transformers import logging\n        logging.set_verbosity_warning()\n        logging.set_verbosity_error()\n        from transformers import AutoConfig\n        from transformers import AutoModelForSequenceClassification\n        \n        #_model_type = 'deberta'\n        _pretrained_model = 'microsoft/deberta-v3-small'\n        config = AutoConfig.from_pretrained(_pretrained_model)\n        #model = AutoModelForSequenceClassification.from_pretrained\n        reinit_layers = 2\n        deberta_model = transformers.TFAutoModel.from_pretrained(_pretrained_model, config=self.config)\n        #_model_type = 'google/bigbird-roberta-base'\n        if reinit_layers > 0:\n            print(f'Reinitializing Last {reinit_layers} Layers ...')\n            #encoder_temp = getattr(self.model, _model_type)\n            for encoder_block in deberta_model.deberta.encoder.layer[-reinit_layers:]:\n            #         print(f'{encoder_block}')\n                for layer in encoder_block.submodules:\n            #for layer in model.deberta.encoder.layer[-reinit_layers:]:\n                #for module in layer.modules():\n                    if isinstance(module, nn.Linear):\n                        module.weight.data.normal_(mean=0.0, std=config.initializer_range)\n                        if module.bias is not None:\n                            module.bias.data.zero_()\n                    elif isinstance(module, nn.Embedding):\n                        module.weight.data.normal_(mean=0.0, std=config.initializer_range)\n                        if module.padding_idx is not None:\n                            module.weight.data[module.padding_idx].zero_()\n                    elif isinstance(module, nn.LayerNorm):\n                        module.bias.data.zero_()\n                        module.weight.data.fill_(1.0)\n    def feature(self, inputs):\n        \n        \n        #This method makes a forward pass through the model, get the last hidden state (embedding)\n        #and pass it through the MeanPooling layer.\n        \n        \n        \n ...

# %%
class MeanPooling(nn.Module):
    def __init__(self):
        super(MeanPooling, self).__init__()
    def forward(self, last_hidden_state, attention_mask):
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        sum_mask = input_mask_expanded.sum(1)
        sum_mask = torch.clamp(sum_mask, min=1e-9)
        mean_embeddings = sum_embeddings / sum_mask
        return mean_embeddings
class CustomModel(nn.Module):
    def __init__(self, cfg, config_path=None, pretrained=False):
        super().__init__()
        self.cfg = cfg
        # Load config by inferencing it from the model name.
        if config_path is None:
            self.config = AutoConfig.from_pretrained(cfg.MODEL, output_hidden_states=True)
            self.config.hidden_dropout = 0.
            self.config.hidden_dropout_prob = 0.
            self.config.attention_dropout = 0.
            self.config.attention_probs_dropout_prob = 0.
        # Load config from a file.
        else:
            self.config = torch.load(config_path)
        if pretrained:
            self.model = AutoModel.from_pretrained(cfg.MODEL, config=self.config)
        else:
            self.model = AutoModel(self.config)
        if self.cfg.GRADIENT_CHECKPOINTING:
            self.model.gradient_checkpointing_enable()
        # Add MeanPooling and Linear head at the end to transform the Model into a RegressionModel
        self.pool = MeanPooling()
        self.fc = nn.Linear(self.config.hidden_size, config.NUM_CLASSES)
        self._init_weights(self.fc)
    def _init_weights(self, module):
        """
        This method initializes weights for different types of layers. The type of layers
        supported are nn.Linear, nn.Embedding and nn.LayerNorm.
        """
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)
    def feature(self, inputs):
        """
        This method makes a forward pass through the model, get the last hidden state (embedding)
        and pass it through the MeanPooling layer.
        """
        outputs = self.model(**inputs)
        last_hidden_states = outputs[0]
        feature = self.pool(last_hidden_states, inputs['attention_mask'])
        return feature
    def forward(self, inputs):
        """
        This method makes a forward pass through the model, the MeanPooling layer and finally
        then through the Linear layer to get a regression value.
        """
        feature = self.feature(inputs)
        output = self.fc(feature)
        return output

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()
    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count
def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)
def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))
def train_epoch(fold, train_loader, model, criterion, optimizer, epoch, scheduler, device):
    """One epoch training pass."""
    model.train() # set model in train mode
    scaler = torch.cuda.amp.GradScaler(enabled=config.APEX) # Automatic Mixed Precision tries to match each op to its appropriate datatype.
    losses = AverageMeter() # initiate AverageMeter to track the loss.
    start = end = time.time() # track the execution time.
    global_step = 0
    # ========== ITERATE OVER TRAIN BATCHES ============
    with tqdm(train_loader, unit="train_batch", desc='Train') as tqdm_train_loader:
        for step, batch in enumerate(tqdm_train_loader):
            inputs = batch.pop("inputs")
            labels = batch.pop("labels")
            inputs = collate(inputs) # collate inputs
            for k, v in inputs.items(): # send each tensor value to `device`
                inputs[k] = v.to(device)
            labels = labels.to(device) # send labels to `device`
            batch_size = labels.size(0)
            with torch.cuda.amp.autocast(enabled=config.APEX):
                y_preds = model(inputs) # forward propagation pass
                loss = criterion(y_preds, labels) # get loss
            if config.GRADIENT_ACCUMULATION_STEPS > 1:
                loss = loss / config.GRADIENT_ACCUMULATION_STEPS
            losses.update(loss.item(), batch_size) # update loss function tracking
            scaler.scale(loss).backward() # backward propagation pass
            grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), config.MAX_GRAD_NORM)
            if (step + 1) % config.GRADIENT_ACCUMULATION_STEPS == 0:
                scaler.step(optimizer) # update optimizer parameters
                scaler.update()
                optimizer.zero_grad() # zero out the gradients
                global_step += 1
                if config.BATCH_SCHEDULER:
                    scheduler.step() # update learning rate
            end = time.time() # get finish time
            # ========== LOG INFO ==========
            if step % config.PRINT_FREQ == 0 or step == (len(train_loader)-1):
                print('Epoch: [{0}][{1}/{2}] '
                      'Elapsed {remain:s} '
                      'Loss: {loss.avg:.4f} '
                      'Grad: {grad_norm:.4f}  '
                      'LR: {lr:.8f}  '
                      .format(epoch+1, step, len(train_loader),
                              remain=timeSince(start, float(step+1)/len(train_loader)),
                              loss=losses,
                              grad_norm=grad_norm,
                              lr=scheduler.get_lr()[0]))
    return losses.avg
def valid_epoch(valid_loader, model, criterion, device):
    model.eval() # set model in evaluation mode
    losses = AverageMeter() # initiate AverageMeter for tracking the loss.
    prediction_dict = {}
    preds = []
    start = end = time.time() # track the execution time.
    with tqdm(valid_loader, unit="valid_batch", desc='Validation') as tqdm_valid_loader:
        for step, batch in enumerate(tqdm_valid_loader):
            inputs = batch.pop("inputs")
            labels = batch.pop("labels")
            student_ids = batch.pop("essay_ids")
            inputs = collate(inputs) # collate inputs
            for k, v in inputs.items():
                inputs[k] = v.to(device) # send inputs to device
            labels = labels.to(device)
            batch_size = labels.size(0)
            with torch.no_grad():
                y_preds = model(inputs) # forward propagation pass
                loss = criterion(y_preds, labels) # get loss
            if config.GRADIENT_ACCUMULATION_STEPS > 1:
                loss = loss / config.GRADIENT_ACCUMULATION_STEPS
            losses.update(loss.item(), batch_size) # update loss function tracking
            preds.append(y_preds.to('cpu').numpy()) # save predictions
            end = time.time() # get finish time
            # ========== LOG INFO ==========
            if step % config.PRINT_FREQ == 0 or step == (len(valid_loader)-1):
                print('EVAL: [{0}/{1}] '
                      'Elapsed {remain:s} '
                      'Loss: {loss.avg:.4f} '
                      .format(step, len(valid_loader),
                              loss=losses,
                              remain=timeSince(start, float(step+1)/len(valid_loader))))
    prediction_dict["predictions"] = np.concatenate(preds) # np.array() of shape (fold_size, target_cols)
    prediction_dict["essay_ids"] = student_ids
    return losses.avg, prediction_dict

# %%
def train_loop(folds, fold):
    LOGGER.info(f"========== Fold: {fold} training ==========")
    # ======== SPLIT ==========
    train_folds = folds[folds['fold'] != fold].reset_index(drop=True)
    valid_folds = folds[folds['fold'] == fold].reset_index(drop=True)
    valid_labels = valid_folds["score"].values
    # ======== DATASETS ==========
    train_dataset = CustomDataset(config, train_folds, tokenizer)
    valid_dataset = CustomDataset(config, valid_folds, tokenizer)
    # ======== DATALOADERS ==========
    train_loader = DataLoader(train_dataset,
                              batch_size=config.BATCH_SIZE_TRAIN, # TODO: split into train and valid
                              shuffle=True,
                              num_workers=config.NUM_WORKERS, pin_memory=True, drop_last=True)
    valid_loader = DataLoader(valid_dataset,
                              batch_size=config.BATCH_SIZE_VALID,
                              shuffle=False,
                              num_workers=config.NUM_WORKERS, pin_memory=True, drop_last=False)
    # ======== MODEL ==========
    model = CustomModel(config, config_path=None, pretrained=True)
    torch.save(model.config, paths.OUTPUT_DIR + '/config.pth')
    model.to(device)
    optimizer_parameters = get_optimizer_grouped_parameters(model,
                                                learning_rate=config.MIN_LR,
                                               weight_decay=config.WEIGHT_DECAY,
                                                      layerwise_learning_rate_decay= config.layerwise_learning_rate_decay)
    optimizer = AdamW(
        optimizer_parameters,
        lr=(config.MIN_LR)*(config.layerwise_learning_rate_decay),
        eps=config.EPS,
        betas=config.BETAS
    )
    num_train_steps = int(len(train_folds) / config.BATCH_SIZE_TRAIN * config.EPOCHS)
    scheduler = get_scheduler(config, optimizer, num_train_steps)
    # ======= LOSS ==========
    # criterion = RMSELoss(reduction="mean") # nn.SmoothL1Loss(reduction='mean')
    criterion = nn.CrossEntropyLoss()
    softmax = nn.Softmax(dim=1)
    best_score = -np.inf
    # ====== ITERATE EPOCHS ========
    for epoch in range(config.EPOCHS):
        start_time = time.time()
        # ======= TRAIN ==========
        avg_loss = train_epoch(fold, train_loader, model, criterion, optimizer, epoch, scheduler, device)
        # ======= EVALUATION ==========
        avg_val_loss, prediction_dict = valid_epoch(valid_loader, model, criterion, device)
        predictions = prediction_dict["predictions"]
        _, predictions = torch.max(softmax(torch.tensor(predictions)), dim=1)
        # ======= SCORING ==========
        score = get_score(valid_labels, predictions)
        elapsed = time.time() - start_time
        LOGGER.info(f'Epoch {epoch+1} - avg_train_loss: {avg_loss:.4f}  avg_val_loss: {avg_val_loss:.4f}  time: {elapsed:.0f}s')
        LOGGER.info(f'Epoch {epoch+1} - Score: {score:.4f}')
        if score > best_score:
            best_score = score
            LOGGER.info(f'Epoch {epoch+1} - Save Best Score: {best_score:.4f} Model')
            torch.save({'model': model.state_dict(),
                        'predictions': predictions},
                        paths.OUTPUT_DIR + f"/{config.MODEL.replace('/', '_')}_fold_{fold}_best.pth")
    predictions = torch.load(paths.OUTPUT_DIR + f"/{config.MODEL.replace('/', '_')}_fold_{fold}_best.pth",
                             map_location=torch.device('cpu'))['predictions']
    valid_folds["pred_score"] = predictions
    torch.cuda.empty_cache()
    gc.collect()
    return valid_folds

# %%
if __name__ == '__main__':
    def get_result(oof_df):
        labels = oof_df["score"].values
        preds = oof_df["pred_score"].values
        score = get_score(labels, preds)
        LOGGER.info(f'Score: {score:<.4f}')
    if config.TRAIN:
        oof_df = pd.DataFrame()
        for fold in range(config.FOLDS):
            if fold in config.TRAIN_FOLDS:
                _oof_df = train_loop(train_df, fold)
                oof_df = pd.concat([oof_df, _oof_df])
                LOGGER.info(f"========== Fold: {fold} result ==========")
                get_result(_oof_df)
        oof_df = oof_df.reset_index(drop=True)
        LOGGER.info(f"========== CV ==========")
        get_result(oof_df)
        oof_df.to_csv(paths.OUTPUT_DIR + '/oof_df.csv', index=False)
# Out:
# ========== Fold: 0 training ==========
# pytorch_model.bin:   0%|          | 0.00/286M [00:00<?, ?B/s]
# Train:   0%|          | 0/3461 [00:00<?, ?train_batch/s]
# Epoch: [1][0/3461] Elapsed 0m 1s (remain 81m 40s) Loss: 1.8853 Grad: inf  LR: 0.00002000
# Epoch: [1][20/3461] Elapsed 0m 5s (remain 15m 58s) Loss: 1.8996 Grad: nan  LR: 0.00002000
# Epoch: [1][40/3461] Elapsed 0m 10s (remain 14m 3s) Loss: 1.8664 Grad: nan  LR: 0.00002000
# Epoch: [1][60/3461] Elapsed 0m 14s (remain 13m 22s) Loss: 1.8736 Grad: nan  LR: 0.00002000
# Epoch: [1][80/3461] Elapsed 0m 18s (remain 13m 2s) Loss: 1.8665 Grad: nan  LR: 0.00001999
# Epoch: [1][100/3461] Elapsed 0m 23s (remain 12m 46s) Loss: 1.8701 Grad: nan  LR: 0.00001999
# Epoch: [1][120/3461] Elapsed 0m 27s (remain 12m 35s) Loss: 1.8687 Grad: nan  LR: 0.00001998
# Epoch: [1][140/3461] Elapsed 0m 31s (remain 12m 26s) Loss: 1.8684 Grad: nan  LR: 0.00001998
# Epoch: [1][160/3461] Elapsed 0m 35s (remain 12m 17s) Loss: 1.8686 Grad: nan  LR: 0.00001997
# Epoch: [1][180/3461] Elapsed 0m 40s (remain 12m 9s) Loss: 1.8676 Grad: nan  LR: 0.00001997
# Epoch: [1][200/3461] Elapsed 0m 44s (remain 12m 1s) Loss: 1.8687 Grad: nan  LR: 0.00001996
# Epoch: [1][220/3461] Elapsed 0m 48s (remain 11m 55s) Loss: 1.8701 Grad: nan  LR: 0.00001995
# Epoch: [1][240/3461] Elapsed 0m 53s (remain 11m 50s) Loss: 1.8697 Grad: nan  LR: 0.00001994
# Epoch: [1][260/3461] Elapsed 0m 57s (remain 11m 46s) Loss: 1.8733 Grad: nan  LR: 0.00001993
# Epoch: [1][280/3461] Elapsed 1m 1s (remain 11m 40s) Loss: 1.8755 Grad: nan  LR: 0.00001992
# Epoch: [1][300/3461] Elapsed 1m 6s (remain 11m 34s) Loss: 1.8755 Grad: nan  LR: 0.00001991
# Epoch: [1][320/3461] Elapsed 1m 10s (remain 11m 30s) Loss: 1.8743 Grad: nan  LR: 0.00001989
# Epoch: [1][340/3461] Elapsed 1m 14s (remain 11m 24s) Loss: 1.8728 Grad: nan  LR: 0.00001988
# Epoch: [1][360/3461] Elapsed 1m 19s (remain 11m 19s) Loss: 1.8713 Grad: nan  LR: 0.00001987
# Epoch: [1][380/3461] Elapsed 1m 23s (remain 11m 15s) Loss: 1.8702 Grad: nan  LR: 0.00001985
# Epoch: [1][400/3461] Elapsed 1m 28s (remain 11m 11s) Loss: 1.8698 Grad: nan  LR: 0.00001983
# Epoch: [1][420/3461] Elapsed 1m 32s (remain 11m 6s) Loss: 1.8729 Grad: nan  LR: 0.00001982
# Epoch: [1][440/3461] Elapsed 1m 36s (remain 11m 2s) Loss: 1.8736 Grad: nan  LR: 0.00001980
# Epoch: [1][460/3461] Elapsed 1m 41s (remain 10m 57s) Loss: 1.8747 Grad: nan  LR: 0.00001978
# Epoch: [1][480/3461] Elapsed 1m 45s (remain 10m 53s) Loss: 1.8747 Grad: nan  LR: 0.00001976
# Epoch: [1][500/3461] Elapsed 1m 49s (remain 10m 48s) Loss: 1.8745 Grad: nan  LR: 0.00001974
# Epoch: [1][520/3461] Elapsed 1m 54s (remain 10m 44s) Loss: 1.8746 Grad: nan  LR: 0.00001972
# Epoch: [1][540/3461] Elapsed 1m 58s (remain 10m 39s) Loss: 1.8752 Grad: nan  LR: 0.00001970
# Epoch: [1][560/3461] Elapsed 2m 2s (remain 10m 35s) Loss: 1.8750 Grad: nan  LR: 0.00001968
# Epoch: [1][580/3461] Elapsed 2m 7s (remain 10m 30s) Loss: 1.8734 Grad: nan  LR: 0.00001965
# Epoch: [1][600/3461] Elapsed 2m 11s (remain 10m 26s) Loss: 1.8720 Grad: nan  LR: 0.00001963
# Epoch: [1][620/3461] Elapsed 2m 16s (remain 10m 22s) Loss: 1.8726 Grad: nan  LR: 0.00001961
# Epoch: [1][640/3461] Elapsed 2m 20s (remain 10m 17s) Loss: 1.8726 Grad: nan  LR: 0.00001958
# Epoch: [1][660/3461] Elapsed 2m 24s (remain 10m 12s) Loss: 1.8731 Grad: nan  LR: 0.00001955
# Epoch: [1][680/3461] Elapsed 2m 28s (remain 10m 8s) Loss: 1.8726 Grad: nan  LR: 0.00001953
# Epoch: [1][700/3461] Elapsed 2m 33s (remain 10m 3s) Loss: 1.8724 Grad: nan  LR: 0.00001950
# Epoch: [1][720/3461] Elapsed 2m 37s (remain 9m 59s) Loss: 1.8709 Grad: nan  LR: 0.00001947
# Epoch: [1][740/3461] Elapsed 2m 41s (remain 9m 54s) Loss: 1.8714 Grad: nan  LR: 0.00001944
# Epoch: [1][760/3461] Elapsed 2m 46s (remain 9m 49s) Loss: 1.8719 Grad: nan  LR: 0.00001941
# Epoch: [1][780/3461] Elapsed 2m 50s (remain 9m 45s) Loss: 1.8711 Grad: nan  LR: 0.00001938
# Epoch: [1][800/3461] Elapsed 2m 54s (remain 9m 41s) Loss: 1.8716 Grad: nan  LR: 0.00001935
# Epoch: [1][820/3461] Elapsed 2m 59s (remain 9m 36s) Loss: 1.8714 Grad: nan  LR: 0.00001931
# Epoch: [1][840/3461] Elapsed 3m 3s (remain 9m 31s) Loss: 1.8710 Grad: nan  LR: 0.00001928
# Epoch: [1][860/3461] Elapsed 3m 7s (remain 9m 27s) Loss: 1.8707 Grad: nan  LR: 0.00001925
# Epoch: [1][880/3461] Elapsed 3m 12s (remain 9m 23s) Loss: 1.8710 Grad: nan  LR: 0.00001921
# Epoch: [1][900/3461] Elapsed 3m 16s (remain 9m 18s) Loss: 1.8712 Grad: nan  LR: 0.00001918
# Epoch: [1][920/3461] Elapsed 3m 21s (remain 9m 14s) Loss: 1.8725 Grad: nan  LR: 0.00001914
# Epoch: [1][940/3461] Elapsed 3m 25s (remain 9m 10s) Loss: 1.8727 Grad: nan  LR: 0.00001910
# Epoch: [1][960/3461] Elapsed 3m 29s (remain 9m 6s) Loss: 1.8715 Grad: nan  LR: 0.00001906
# Epoch: [1][980/3461] Elapsed 3m 34s (remain 9m 1s) Loss: 1.8718 Grad: nan  LR: 0.00001903
# Epoch: [1][1000/3461] Elapsed 3m 38s (remain 8m 57s) Loss: 1.8716 Grad: nan  LR: 0.00001899
# Epoch: [1][1020/3461] Elapsed 3m 42s (remain 8m 52s) Loss: 1.8710 Grad: nan  LR: 0.00001895
# Epoch: [1][1040/3461] Elapsed 3m 47s (remain 8m 47s) Loss: 1.8711 Grad: nan  LR: 0.00001890
# Epoch: [1][1060/3461] Elapsed 3m 51s (remain 8m 43s) Loss: 1.8714 Grad: nan  LR: 0.00001886
# Epoch: [1][1080/3461] Elapsed 3m 55s (remain 8m 38s) Loss: 1.8721 Grad: nan  LR: 0.00001882
# Epoch: [1][1100/3461] Elapsed 3m 59s (remain 8m 34s) Loss: 1.8723 Grad: nan  LR: 0.00001878
# Epoch: [1][1120/3461] Elapsed 4m 4s (remain 8m 29s) Loss: 1.8725 Grad: nan  LR: 0.00001873
# Epoch: [1][1140/3461] Elapsed 4m 8s (remain 8m 25s) Loss: 1.8720 Grad: nan  LR: 0.00001869
# Epoch: [1][1160/3461] Elapsed 4m 13s (remain 8m 21s) Loss: 1.8704 Grad: nan  LR: 0.00001864
# Epoch: [1][1180/3461] Elapsed 4m 17s (remain 8m 17s) Loss: 1.8700 Grad: nan  LR: 0.00001860
# Epoch: [1][1200/3461] Elapsed 4m 22s (remain 8m 13s) Loss: 1.8703 Grad: nan  LR: 0.00001855
# Epoch: [1][1220/3461] Elapsed 4m 26s (remain 8m 8s) Loss: 1.8695 Grad: nan  LR: 0.00001850
# Epoch: [1][1240/3461] Elapsed 4m 30s (remain 8m 4s) Loss: 1.8697 Grad: nan  LR: 0.00001846
# Epoch: [1][1260/3461] Elapsed 4m 35s (remain 7m 59s) Loss: 1.8697 Grad: nan  LR: 0.00001841
# Epoch: [1][1280/3461] Elapsed 4m 39s (remain 7m 55s) Loss: 1.8701 Grad: nan  LR: 0.00001836
# Epoch: [1][1300/3461] Elapsed 4m 43s (remain 7m 51s) Loss: 1.8698 Grad: nan  LR: 0.00001831
# Epoch: [1][1320/3461] Elapsed 4m 48s (remain 7m 46s) Loss: 1.8702 Grad: nan  LR: 0.00001826
# Epoch: [1][1340/3461] Elapsed 4m 52s (remain 7m 42s) Loss: 1.8700 Grad: nan  LR: 0.00001820
# Epoch: [1][1360/3461] Elapsed 4m 57s (remain 7m 38s) Loss: 1.8701 Grad: nan  LR: 0.00001815
# Epoch: [1][1380/3461] Elapsed 5m 1s (remain 7m 34s) Loss: 1.8699 Grad: nan  LR: 0.00001810
# Epoch: [1][1400/3461] Elapsed 5m 5s (remain 7m 29s) Loss: 1.8704 Grad: nan  LR: 0.00001805
# Epoch: [1][1420/3461] Elapsed 5m 10s (remain 7m 25s) Loss: 1.8709 Grad: nan  LR: 0.00001799
# Epoch: [1][1440/3461] Elapsed 5m 14s (remain 7m 21s) Loss: 1.8711 Grad: nan  LR: 0.00001794
# Epoch: [1][1460/3461] Elapsed 5m 18s (remain 7m 16s) Loss: 1.8708 Grad: nan  LR: 0.00001788
# Epoch: [1][1480/3461] Elapsed 5m 23s (remain 7m 12s) Loss: 1.8718 Grad: nan  LR: 0.00001782
# Epoch: [1][1500/3461] Elapsed 5m 27s (remain 7m 7s) Loss: 1.8717 Grad: nan  LR: 0.00001777
# Epoch: [1][1520/3461] Elapsed 5m 31s (remain 7m 3s) Loss: 1.8715 Grad: nan  LR: 0.00001771
# Epoch: [1][1540/3461] Elapsed 5m 36s (remain 6m 58s) Loss: 1.8720 Grad: nan  LR: 0.00001765
# Epoch: [1][1560/3461] Elapsed 5m 40s (remain 6m 54s) Loss: 1.8718 Grad: nan  LR: 0.00001759
# Epoch: [1][1580/3461] Elapsed 5m 44s (remain 6m 49s) Loss: 1.8718 Grad: nan  LR: 0.00001753
# Epoch: [1][1600/3461] Elapsed 5m 48s (remain 6m 44s) Loss: 1.8711 Grad: nan  LR: 0.00001747
# Epoch: [1][1620/3461] Elapsed 5m 52s (remain 6m 40s) Loss: 1.8711 Grad: nan  LR: 0.00001741
# Epoch: [1][1640/3461] Elapsed 5m 57s (remain 6m 36s) Loss: 1.8707 Grad: nan  LR: 0.00001735
# Epoch: [1][1660/3461] Elapsed 6m 1s (remain 6m 31s) Loss: 1.8707 Grad: nan  LR: 0.00001729
# Epoch: [1][1680/3461] Elapsed 6m 6s (remain 6m 27s) Loss: 1.8708 Grad: nan  LR: 0.00001723
# Epoch: [1][1700/3461] Elapsed 6m 10s (remain 6m 23s) Loss: 1.8701 Grad: nan  LR: 0.00001717
# Epoch: [1][1720/3461] Elapsed 6m 14s (remain 6m 18s) Loss: 1.8706 Grad: nan  LR: 0.00001710
# Epoch: [1][1740/3461] Elapsed 6m 19s (remain 6m 14s) Loss: 1.8701 Grad: nan  LR: 0.00001704
# Epoch: [1][1760/3461] Elapsed 6m 23s (remain 6m 10s) Loss: 1.8702 Grad: nan  LR: 0.00001697
# Epoch: [1][1780/3461] Elapsed 6m 27s (remain 6m 5s) Loss: 1.8703 Grad: nan  LR: 0.00001691
# Epoch: [1][1800/3461] Elapsed 6m 32s (remain 6m 1s) Loss: 1.8698 Grad: nan  LR: 0.00001684
# Epoch: [1][1820/3461] Elapsed 6m 36s (remain 5m 57s) Loss: 1.8698 Grad: nan  LR: 0.00001677
# Epoch: [1][1840/3461] Elapsed 6m 40s (remain 5m 52s) Loss: 1.8694 Grad: nan  LR: 0.00001671
# Epoch: [1][1860/3461] Elapsed 6m 45s (remain 5m 48s) Loss: 1.8694 Grad: nan  LR: 0.00001664
# Epoch: [1][1880/3461] Elapsed 6m 49s (remain 5m 43s) Loss: 1.8691 Grad: nan  LR: 0.00001657
# Epoch: [1][1900/3461] Elapsed 6m 53s (remain 5m 39s) Loss: 1.8694 Grad: nan  LR: 0.00001650
# Epoch: [1][1920/3461] Elapsed 6m 58s (remain 5m 35s) Loss: 1.8694 Grad: nan  LR: 0.00001643
# Epoch: [1][1940/3461] Elapsed 7m 2s (remain 5m 30s) Loss: 1.8695 Grad: nan  LR: 0.00001636
# Epoch: [1][1960/3461] Elapsed 7m 6s (remain 5m 26s) Loss: 1.8693 Grad: nan  LR: 0.00001629
# Epoch: [1][1980/3461] Elapsed 7m 10s (remain 5m 21s) Loss: 1.8690 Grad: nan  LR: 0.00001622
# Epoch: [1][2000/3461] Elapsed 7m 15s (remain 5m 17s) Loss: 1.8687 Grad: nan  LR: 0.00001615
# Epoch: [1][2020/3461] Elapsed 7m 19s (remain 5m 13s) Loss: 1.8688 Grad: nan  LR: 0.00001608
# Epoch: [1][2040/3461] Elapsed 7m 23s (remain 5m 8s) Loss: 1.8688 Grad: nan  LR: 0.00001601
# Epoch: [1][2060/3461] Elapsed 7m 28s (remain 5m 4s) Loss: 1.8684 Grad: nan  LR: 0.00001593
# Epoch: [1][2080/3461] Elapsed 7m 32s (remain 5m 0s) Loss: 1.8686 Grad: nan  LR: 0.00001586
# Epoch: [1][2100/3461] Elapsed 7m 36s (remain 4m 55s) Loss: 1.8688 Grad: nan  LR: 0.00001579
# Epoch: [1][2120/3461] Elapsed 7m 41s (remain 4m 51s) Loss: 1.8690 Grad: nan  LR: 0.00001571
# Epoch: [1][2140/3461] Elapsed 7m 45s (remain 4m 47s) Loss: 1.8688 Grad: nan  LR: 0.00001564
# Epoch: [1][2160/3461] Elapsed 7m 49s (remain 4m 42s) Loss: 1.8687 Grad: nan  LR: 0.00001556
# Epoch: [1][2180/3461] Elapsed 7m 54s (remain 4m 38s) Loss: 1.8690 Grad: nan  LR: 0.00001549
# Epoch: [1][2200/3461] Elapsed 7m 58s (remain 4m 33s) Loss: 1.8693 Grad: nan  LR: 0.00001541
# Epoch: [1][2220/3461] Elapsed 8m 2s (remain 4m 29s) Loss: 1.8693 Grad: nan  LR: 0.00001534
# Epoch: [1][2240/3461] Elapsed 8m 6s (remain 4m 25s) Loss: 1.8697 Grad: nan  LR: 0.00001526
# Epoch: [1][2260/3461] Elapsed 8m 11s (remain 4m 20s) Loss: 1.8701 Grad: nan  LR: 0.00001518
# Epoch: [1][2280/3461] Elapsed 8m 15s (remain 4m 16s) Loss: 1.8704 Grad: nan  LR: 0.00001510
# Epoch: [1][2300/3461] Elapsed 8m 19s (remain 4m 11s) Loss: 1.8702 Grad: nan  LR: 0.00001502
# Epoch: [1][2320/3461] Elapsed 8m 24s (remain 4m 7s) Loss: 1.8701 Grad: nan  LR: 0.00001495
# Epoch: [1][2340/3461] Elapsed 8m 28s (remain 4m 3s) Loss: 1.8702 Grad: nan  LR: 0.00001487
# Epoch: [1][2360/3461] Elapsed 8m 33s (remain 3m 59s) Loss: 1.8701 Grad: nan  LR: 0.00001479
# Epoch: [1][2380/3461] Elapsed 8m 37s (remain 3m 54s) Loss: 1.8700 Grad: nan  LR: 0.00001471
# Epoch: [1][2400/3461] Elapsed 8m 41s (remain 3m 50s) Loss: 1.8701 Grad: nan  LR: 0.00001463
# Epoch: [1][2420/3461] Elapsed 8m 46s (remain 3m 45s) Loss: 1.8701 Grad: nan  LR: 0.00001455
# Epoch: [1][2440/3461] Elapsed 8m 50s (remain 3m 41s) Loss: 1.8701 Grad: nan  LR: 0.00001447
# Epoch: [1][2460/3461] Elapsed 8m 54s (remain 3m 37s) Loss: 1.8701 Grad: nan  LR: 0.00001438
# Epoch: [1][2480/3461] Elapsed 8m 59s (remain 3m 32s) Loss: 1.8699 Grad: nan  LR: 0.00001430
# Epoch: [1][2500/3461] Elapsed 9m 3s (remain 3m 28s) Loss: 1.8696 Grad: nan  LR: 0.00001422
# Epoch: [1][2520/3461] Elapsed 9m 7s (remain 3m 24s) Loss: 1.8697 Grad: nan  LR: 0.00001414
# Epoch: [1][2540/3461] Elapsed 9m 11s (remain 3m 19s) Loss: 1.8694 Grad: nan  LR: 0.00001406
# Epoch: [1][2560/3461] Elapsed 9m 16s (remain 3m 15s) Loss: 1.8691 Grad: nan  LR: 0.00001397
# Epoch: [1][2580/3461] Elapsed 9m 20s (remain 3m 11s) Loss: 1.8690 Grad: nan  LR: 0.00001389
# Epoch: [1][2600/3461] Elapsed 9m 24s (remain 3m 6s) Loss: 1.8693 Grad: nan  LR: 0.00001380
# Epoch: [1][2620/3461] Elapsed 9m 29s (remain 3m 2s) Loss: 1.8693 Grad: nan  LR: 0.00001372
# Epoch: [1][2640/3461] Elapsed 9m 33s (remain 2m 58s) Loss: 1.8690 Grad: nan  LR: 0.00001364
# Epoch: [1][2660/3461] Elapsed 9m 38s (remain 2m 53s) Loss: 1.8690 Grad: nan  LR: 0.00001355
# Epoch: [1][2680/3461] Elapsed 9m 42s (remain 2m 49s) Loss: 1.8692 Grad: nan  LR: 0.00001347
# Epoch: [1][2700/3461] Elapsed 9m 46s (remain 2m 45s) Loss: 1.8691 Grad: nan  LR: 0.00001338
# Epoch: [1][2720/3461] Elapsed 9m 51s (remain 2m 40s) Loss: 1.8695 Grad: nan  LR: 0.00001330
# Epoch: [1][2740/3461] Elapsed 9m 55s (remain 2m 36s) Loss: 1.8699 Grad: nan  LR: 0.00001321
# Epoch: [1][2760/3461] Elapsed 9m 59s (remain 2m 32s) Loss: 1.8697 Grad: nan  LR: 0.00001312
# Epoch: [1][2780/3461] Elapsed 10m 4s (remain 2m 27s) Loss: 1.8699 Grad: nan  LR: 0.00001304
# Epoch: [1][2800/3461] Elapsed 10m 8s (remain 2m 23s) Loss: 1.8698 Grad: nan  LR: 0.00001295
# Epoch: [1][2820/3461] Elapsed 10m 12s (remain 2m 19s) Loss: 1.8698 Grad: nan  LR: 0.00001286
# Epoch: [1][2840/3461] Elapsed 10m 17s (remain 2m 14s) Loss: 1.8699 Grad: nan  LR: 0.00001278
# Epoch: [1][2860/3461] Elapsed 10m 21s (remain 2m 10s) Loss: 1.8696 Grad: nan  LR: 0.00001269
# Epoch: [1][2880/3461] Elapsed 10m 25s (remain 2m 6s) Loss: 1.8697 Grad: nan  LR: 0.00001260
# Epoch: [1][2900/3461] Elapsed 10m 30s (remain 2m 1s) Loss: 1.8698 Grad: nan  LR: 0.00001251
# Epoch: [1][2920/3461] Elapsed 10m 34s (remain 1m 57s) Loss: 1.8698 Grad: nan  LR: 0.00001243
# Epoch: [1][2940/3461] Elapsed 10m 38s (remain 1m 52s) Loss: 1.8700 Grad: nan  LR: 0.00001234
# Epoch: [1][2960/3461] Elapsed 10m 42s (remain 1m 48s) Loss: 1.8699 Grad: nan  LR: 0.00001225
# Epoch: [1][2980/3461] Elapsed 10m 47s (remain 1m 44s) Loss: 1.8698 Grad: nan  LR: 0.00001216
# Epoch: [1][3000/3461] Elapsed 10m 51s (remain 1m 39s) Loss: 1.8699 Grad: nan  LR: 0.00001207
# Epoch: [1][3020/3461] Elapsed 10m 55s (remain 1m 35s) Loss: 1.8699 Grad: nan  LR: 0.00001198
# Epoch: [1][3040/3461] Elapsed 11m 0s (remain 1m 31s) Loss: 1.8699 Grad: nan  LR: 0.00001189
# Epoch: [1][3060/3461] Elapsed 11m 4s (remain 1m 26s) Loss: 1.8699 Grad: nan  LR: 0.00001181
# Epoch: [1][3080/3461] Elapsed 11m 8s (remain 1m 22s) Loss: 1.8699 Grad: nan  LR: 0.00001172
# Epoch: [1][3100/3461] Elapsed 11m 13s (remain 1m 18s) Loss: 1.8700 Grad: nan  LR: 0.00001163
# Epoch: [1][3120/3461] Elapsed 11m 17s (remain 1m 13s) Loss: 1.8697 Grad: nan  LR: 0.00001154
# Epoch: [1][3140/3461] Elapsed 11m 21s (remain 1m 9s) Loss: 1.8696 Grad: nan  LR: 0.00001145
# Epoch: [1][3160/3461] Elapsed 11m 26s (remain 1m 5s) Loss: 1.8698 Grad: nan  LR: 0.00001136
# Epoch: [1][3180/3461] Elapsed 11m 30s (remain 1m 0s) Loss: 1.8698 Grad: nan  LR: 0.00001127
# Epoch: [1][3200/3461] Elapsed 11m 34s (remain 0m 56s) Loss: 1.8696 Grad: nan  LR: 0.00001118
# Epoch: [1][3220/3461] Elapsed 11m 39s (remain 0m 52s) Loss: 1.8696 Grad: nan  LR: 0.00001109
# Epoch: [1][3240/3461] Elapsed 11m 43s (remain 0m 47s) Loss: 1.8692 Grad: nan  LR: 0.00001100
# Epoch: [1][3260/3461] Elapsed 11m 48s (remain 0m 43s) Loss: 1.8693 Grad: nan  LR: 0.00001091
# Epoch: [1][3280/3461] Elapsed 11m 52s (remain 0m 39s) Loss: 1.8696 Grad: nan  LR: 0.00001082
# Epoch: [1][3300/3461] Elapsed 11m 56s (remain 0m 34s) Loss: 1.8698 Grad: nan  LR: 0.00001073
# Epoch: [1][3320/3461] Elapsed 12m 0s (remain 0m 30s) Loss: 1.8696 Grad: nan  LR: 0.00001063
# Epoch: [1][3340/3461] Elapsed 12m 5s (remain 0m 26s) Loss: 1.8696 Grad: nan  LR: 0.00001054
# Epoch: [1][3360/3461] Elapsed 12m 9s (remain 0m 21s) Loss: 1.8695 Grad: nan  LR: 0.00001045
# Epoch: [1][3380/3461] Elapsed 12m 13s (remain 0m 17s) Loss: 1.8694 Grad: nan  LR: 0.00001036
# Epoch: [1][3400/3461] Elapsed 12m 18s (remain 0m 13s) Loss: 1.8692 Grad: nan  LR: 0.00001027
# Epoch: [1][3420/3461] Elapsed 12m 22s (remain 0m 8s) Loss: 1.8691 Grad: nan  LR: 0.00001018
# Epoch: [1][3440/3461] Elapsed 12m 26s (remain 0m 4s) Loss: 1.8693 Grad: nan  LR: 0.00001009
# Epoch: [1][3460/3461] Elapsed 12m 31s (remain 0m 0s) Loss: 1.8690 Grad: nan  LR: 0.00001000
# Validation:   0%|          | 0/866 [00:00<?, ?valid_batch/s]
# EVAL: [0/866] Elapsed 0m 0s (remain 1m 15s) Loss: 1.8455
# EVAL: [20/866] Elapsed 0m 1s (remain 0m 51s) Loss: 1.8804
# EVAL: [40/866] Elapsed 0m 2s (remain 0m 50s) Loss: 1.8857
# EVAL: [60/866] Elapsed 0m 3s (remain 0m 49s) Loss: 1.8786
# EVAL: [80/866] Elapsed 0m 4s (remain 0m 47s) Loss: 1.8705
# EVAL: [100/866] Elapsed 0m 6s (remain 0m 46s) Loss: 1.8729
# EVAL: [120/866] Elapsed 0m 7s (remain 0m 45s) Loss: 1.8750
# EVAL: [140/866] Elapsed 0m 8s (remain 0m 43s) Loss: 1.8746
# EVAL: [160/866] Elapsed 0m 9s (remain 0m 42s) Loss: 1.8788
# EVAL: [180/866] Elapsed 0m 10s (remain 0m 41s) Loss: 1.8740
# EVAL: [200/866] Elapsed 0m 12s (remain 0m 40s) Loss: 1.8759
# EVAL: [220/866] Elapsed 0m 13s (remain 0m 38s) Loss: 1.8728
# EVAL: [240/866] Elapsed 0m 14s (remain 0m 37s) Loss: 1.8748
# EVAL: [260/866] Elapsed 0m 15s (remain 0m 36s) Loss: 1.8717
# EVAL: [280/866] Elapsed 0m 16s (remain 0m 35s) Loss: 1.8739
# EVAL: [300/866] Elapsed 0m 18s (remain 0m 34s) Loss: 1.8727
# EVAL: [320/866] Elapsed 0m 19s (remain 0m 33s) Loss: 1.8733
# EVAL: [340/866] Elapsed 0m 20s (remain 0m 31s) Loss: 1.8723
# EVAL: [360/866] Elapsed 0m 21s (remain 0m 30s) Loss: 1.8730
# EVAL: [380/866] Elapsed 0m 23s (remain 0m 29s) Loss: 1.8723
# EVAL: [400/866] Elapsed 0m 24s (remain 0m 28s) Loss: 1.8733
# EVAL: [420/866] Elapsed 0m 25s (remain 0m 26s) Loss: 1.8729
# EVAL: [440/866] Elapsed 0m 26s (remain 0m 25s) Loss: 1.8722
# EVAL: [460/866] Elapsed 0m 27s (remain 0m 24s) Loss: 1.8712
# EVAL: [480/866] Elapsed 0m 29s (remain 0m 23s) Loss: 1.8707
# EVAL: [500/866] Elapsed 0m 30s (remain 0m 22s) Loss: 1.8734
# EVAL: [520/866] Elapsed 0m 31s (remain 0m 20s) Loss: 1.8724
# EVAL: [540/866] Elapsed 0m 32s (remain 0m 19s) Loss: 1.8716
# EVAL: [560/866] Elapsed 0m 34s (remain 0m 18s) Loss: 1.8706
# EVAL: [580/866] Elapsed 0m 35s (remain 0m 17s) Loss: 1.8699
# EVAL: [600/866] Elapsed 0m 36s (remain 0m 16s) Loss: 1.8690
# EVAL: [620/866] Elapsed 0m 37s (remain 0m 14s) Loss: 1.8680
# EVAL: [640/866] Elapsed 0m 38s (remain 0m 13s) Loss: 1.8682
# EVAL: [660/866] Elapsed 0m 40s (remain 0m 12s) Loss: 1.8668
# EVAL: [680/866] Elapsed 0m 41s (remain 0m 11s) Loss: 1.8665
# EVAL: [700/866] Elapsed 0m 42s (remain 0m 10s) Loss: 1.8650
# EVAL: [720/866] Elapsed 0m 43s (remain 0m 8s) Loss: 1.8635
# EVAL: [740/866] Elapsed 0m 44s (remain 0m 7s) Loss: 1.8638
# EVAL: [760/866] Elapsed 0m 46s (remain 0m 6s) Loss: 1.8623
# EVAL: [780/866] Elapsed 0m 47s (remain 0m 5s) Loss: 1.8627
# EVAL: [800/866] Elapsed 0m 48s (remain 0m 3s) Loss: 1.8623
# EVAL: [820/866] Elapsed 0m 49s (remain 0m 2s) Loss: 1.8623
# EVAL: [840/866] Elapsed 0m 51s (remain 0m 1s) Loss: 1.8621
# EVAL: [860/866] Elapsed 0m 52s (remain 0m 0s) Loss: 1.8647
# Epoch 1 - avg_train_loss: 1.8690  avg_val_loss: 1.8663  time: 804s
# Epoch 1 - Score: 0.0763
# Epoch 1 - Save Best Score: 0.0763 Model
# EVAL: [865/866] Elapsed 0m 52s (remain 0m 0s) Loss: 1.8663
# Train:   0%|          | 0/3461 [00:00<?, ?train_batch/s]
# Epoch: [2][0/3461] Elapsed 0m 0s (remain 13m 52s) Loss: 1.8757 Grad: nan  LR: 0.00001000
# Epoch: [2][20/3461] Elapsed 0m 4s (remain 13m 0s) Loss: 1.8746 Grad: nan  LR: 0.00000990
# Epoch: [2][40/3461] Elapsed 0m 9s (remain 12m 48s) Loss: 1.8674 Grad: nan  LR: 0.00000981
# Epoch: [2][60/3461] Elapsed 0m 13s (remain 12m 27s) Loss: 1.8877 Grad: nan  LR: 0.00000972
# Epoch: [2][80/3461] Elapsed 0m 17s (remain 12m 25s) Loss: 1.8873 Grad: nan  LR: 0.00000963
# Epoch: [2][100/3461] Elapsed 0m 22s (remain 12m 14s) Loss: 1.8803 Grad: nan  LR: 0.00000954
# Epoch: [2][120/3461] Elapsed 0m 26s (remain 12m 10s) Loss: 1.8769 Grad: nan  LR: 0.00000945
# Epoch: [2][140/3461] Elapsed 0m 30s (remain 12m 4s) Loss: 1.8792 Grad: nan  LR: 0.00000936
# Epoch: [2][160/3461] Elapsed 0m 35s (remain 11m 59s) Loss: 1.8755 Grad: nan  LR: 0.00000927
# Epoch: [2][180/3461] Elapsed 0m 39s (remain 11m 52s) Loss: 1.8793 Grad: nan  LR: 0.00000918
# Epoch: [2][200/3461] Elapsed 0m 43s (remain 11m 48s) Loss: 1.8793 Grad: nan  LR: 0.00000909
# Epoch: [2][220/3461] Elapsed 0m 48s (remain 11m 45s) Loss: 1.8792 Grad: nan  LR: 0.00000900
# Epoch: [2][240/3461] Elapsed 0m 52s (remain 11m 39s) Loss: 1.8830 Grad: nan  LR: 0.00000891
# Epoch: [2][260/3461] Elapsed 0m 56s (remain 11m 33s) Loss: 1.8794 Grad: nan  LR: 0.00000882
# Epoch: [2][280/3461] Elapsed 1m 0s (remain 11m 30s) Loss: 1.8781 Grad: nan  LR: 0.00000873
# Epoch: [2][300/3461] Elapsed 1m 5s (remain 11m 24s) Loss: 1.8771 Grad: nan  LR: 0.00000864
# Epoch: [2][320/3461] Elapsed 1m 9s (remain 11m 21s) Loss: 1.8759 Grad: nan  LR: 0.00000855
# Epoch: [2][340/3461] Elapsed 1m 13s (remain 11m 15s) Loss: 1.8752 Grad: nan  LR: 0.00000846
# Epoch: [2][360/3461] Elapsed 1m 18s (remain 11m 12s) Loss: 1.8754 Grad: nan  LR: 0.00000837
# Epoch: [2][380/3461] Elapsed 1m 22s (remain 11m 8s) Loss: 1.8729 Grad: nan  LR: 0.00000828
# Epoch: [2][400/3461] Elapsed 1m 26s (remain 11m 3s) Loss: 1.8734 Grad: nan  LR: 0.00000819
# Epoch: [2][420/3461] Elapsed 1m 31s (remain 10m 59s) Loss: 1.8705 Grad: nan  LR: 0.00000810
# Epoch: [2][440/3461] Elapsed 1m 35s (remain 10m 55s) Loss: 1.8691 Grad: nan  LR: 0.00000801
# Epoch: [2][460/3461] Elapsed 1m 40s (remain 10m 51s) Loss: 1.8699 Grad: nan  LR: 0.00000792
# Epoch: [2][480/3461] Elapsed 1m 44s (remain 10m 47s) Loss: 1.8696 Grad: nan  LR: 0.00000783
# Epoch: [2][500/3461] Elapsed 1m 48s (remain 10m 41s) Loss: 1.8701 Grad: nan  LR: 0.00000775
# Epoch: [2][520/3461] Elapsed 1m 53s (remain 10m 37s) Loss: 1.8701 Grad: nan  LR: 0.00000766
# Epoch: [2][540/3461] Elapsed 1m 57s (remain 10m 33s) Loss: 1.8714 Grad: nan  LR: 0.00000757
# Epoch: [2][560/3461] Elapsed 2m 1s (remain 10m 29s) Loss: 1.8706 Grad: nan  LR: 0.00000748
# Epoch: [2][580/3461] Elapsed 2m 6s (remain 10m 25s) Loss: 1.8715 Grad: nan  LR: 0.00000739
# Epoch: [2][600/3461] Elapsed 2m 10s (remain 10m 20s) Loss: 1.8699 Grad: nan  LR: 0.00000731
# Epoch: [2][620/3461] Elapsed 2m 14s (remain 10m 16s) Loss: 1.8706 Grad: nan  LR: 0.00000722
# Epoch: [2][640/3461] Elapsed 2m 18s (remain 10m 11s) Loss: 1.8713 Grad: nan  LR: 0.00000713
# Epoch: [2][660/3461] Elapsed 2m 23s (remain 10m 7s) Loss: 1.8719 Grad: nan  LR: 0.00000704
# Epoch: [2][680/3461] Elapsed 2m 27s (remain 10m 3s) Loss: 1.8724 Grad: nan  LR: 0.00000696
# Epoch: [2][700/3461] Elapsed 2m 32s (remain 9m 58s) Loss: 1.8713 Grad: nan  LR: 0.00000687
# Epoch: [2][720/3461] Elapsed 2m 36s (remain 9m 54s) Loss: 1.8714 Grad: nan  LR: 0.00000679
# Epoch: [2][740/3461] Elapsed 2m 40s (remain 9m 50s) Loss: 1.8728 Grad: nan  LR: 0.00000670
# Epoch: [2][760/3461] Elapsed 2m 44s (remain 9m 45s) Loss: 1.8736 Grad: nan  LR: 0.00000661
# Epoch: [2][780/3461] Elapsed 2m 49s (remain 9m 41s) Loss: 1.8731 Grad: nan  LR: 0.00000653
# Epoch: [2][800/3461] Elapsed 2m 53s (remain 9m 36s) Loss: 1.8733 Grad: nan  LR: 0.00000644
# Epoch: [2][820/3461] Elapsed 2m 57s (remain 9m 32s) Loss: 1.8740 Grad: nan  LR: 0.00000636
# Epoch: [2][840/3461] Elapsed 3m 2s (remain 9m 28s) Loss: 1.8736 Grad: nan  LR: 0.00000628
# Epoch: [2][860/3461] Elapsed 3m 6s (remain 9m 23s) Loss: 1.8739 Grad: nan  LR: 0.00000619
# Epoch: [2][880/3461] Elapsed 3m 10s (remain 9m 18s) Loss: 1.8735 Grad: nan  LR: 0.00000611
# Epoch: [2][900/3461] Elapsed 3m 15s (remain 9m 14s) Loss: 1.8729 Grad: nan  LR: 0.00000602
# Epoch: [2][920/3461] Elapsed 3m 19s (remain 9m 10s) Loss: 1.8729 Grad: nan  LR: 0.00000594
# Epoch: [2][940/3461] Elapsed 3m 23s (remain 9m 6s) Loss: 1.8726 Grad: nan  LR: 0.00000586
# Epoch: [2][960/3461] Elapsed 3m 28s (remain 9m 1s) Loss: 1.8727 Grad: nan  LR: 0.00000578
# Epoch: [2][980/3461] Elapsed 3m 32s (remain 8m 57s) Loss: 1.8728 Grad: nan  LR: 0.00000569
# Epoch: [2][1000/3461] Elapsed 3m 36s (remain 8m 52s) Loss: 1.8731 Grad: nan  LR: 0.00000561
# Epoch: [2][1020/3461] Elapsed 3m 41s (remain 8m 48s) Loss: 1.8733 Grad: nan  LR: 0.00000553
# Epoch: [2][1040/3461] Elapsed 3m 45s (remain 8m 44s) Loss: 1.8732 Grad: nan  LR: 0.00000545
# Epoch: [2][1060/3461] Elapsed 3m 49s (remain 8m 40s) Loss: 1.8732 Grad: nan  LR: 0.00000537
# Epoch: [2][1080/3461] Elapsed 3m 54s (remain 8m 35s) Loss: 1.8727 Grad: nan  LR: 0.00000529
# Epoch: [2][1100/3461] Elapsed 3m 58s (remain 8m 31s) Loss: 1.8725 Grad: nan  LR: 0.00000521
# Epoch: [2][1120/3461] Elapsed 4m 2s (remain 8m 27s) Loss: 1.8720 Grad: nan  LR: 0.00000513
# Epoch: [2][1140/3461] Elapsed 4m 7s (remain 8m 22s) Loss: 1.8724 Grad: nan  LR: 0.00000505
# Epoch: [2][1160/3461] Elapsed 4m 11s (remain 8m 18s) Loss: 1.8722 Grad: nan  LR: 0.00000497
# Epoch: [2][1180/3461] Elapsed 4m 15s (remain 8m 14s) Loss: 1.8719 Grad: nan  LR: 0.00000489
# Epoch: [2][1200/3461] Elapsed 4m 20s (remain 8m 9s) Loss: 1.8721 Grad: nan  LR: 0.00000482
# Epoch: [2][1220/3461] Elapsed 4m 24s (remain 8m 5s) Loss: 1.8720 Grad: nan  LR: 0.00000474
# Epoch: [2][1240/3461] Elapsed 4m 28s (remain 8m 1s) Loss: 1.8718 Grad: nan  LR: 0.00000466
# Epoch: [2][1260/3461] Elapsed 4m 33s (remain 7m 56s) Loss: 1.8710 Grad: nan  LR: 0.00000458
# Epoch: [2][1280/3461] Elapsed 4m 37s (remain 7m 52s) Loss: 1.8714 Grad: nan  LR: 0.00000451
# Epoch: [2][1300/3461] Elapsed 4m 41s (remain 7m 48s) Loss: 1.8717 Grad: nan  LR: 0.00000443
# Epoch: [2][1320/3461] Elapsed 4m 46s (remain 7m 43s) Loss: 1.8714 Grad: nan  LR: 0.00000436
# Epoch: [2][1340/3461] Elapsed 4m 50s (remain 7m 39s) Loss: 1.8710 Grad: nan  LR: 0.00000428
# Epoch: [2][1360/3461] Elapsed 4m 54s (remain 7m 35s) Loss: 1.8708 Grad: nan  LR: 0.00000421
# Epoch: [2][1380/3461] Elapsed 4m 59s (remain 7m 30s) Loss: 1.8711 Grad: nan  LR: 0.00000413
# Epoch: [2][1400/3461] Elapsed 5m 3s (remain 7m 26s) Loss: 1.8712 Grad: nan  LR: 0.00000406
# Epoch: [2][1420/3461] Elapsed 5m 8s (remain 7m 22s) Loss: 1.8708 Grad: nan  LR: 0.00000399
# Epoch: [2][1440/3461] Elapsed 5m 12s (remain 7m 18s) Loss: 1.8707 Grad: nan  LR: 0.00000392
# Epoch: [2][1460/3461] Elapsed 5m 16s (remain 7m 13s) Loss: 1.8704 Grad: nan  LR: 0.00000384
# Epoch: [2][1480/3461] Elapsed 5m 21s (remain 7m 9s) Loss: 1.8703 Grad: nan  LR: 0.00000377
# Epoch: [2][1500/3461] Elapsed 5m 25s (remain 7m 5s) Loss: 1.8703 Grad: nan  LR: 0.00000370
# Epoch: [2][1520/3461] Elapsed 5m 29s (remain 7m 0s) Loss: 1.8702 Grad: nan  LR: 0.00000363
# Epoch: [2][1540/3461] Elapsed 5m 34s (remain 6m 56s) Loss: 1.8700 Grad: nan  LR: 0.00000356
# Epoch: [2][1560/3461] Elapsed 5m 38s (remain 6m 52s) Loss: 1.8699 Grad: nan  LR: 0.00000349
# Epoch: [2][1580/3461] Elapsed 5m 42s (remain 6m 47s) Loss: 1.8698 Grad: nan  LR: 0.00000342
# Epoch: [2][1600/3461] Elapsed 5m 47s (remain 6m 43s) Loss: 1.8698 Grad: nan  LR: 0.00000336
# Epoch: [2][1620/3461] Elapsed 5m 51s (remain 6m 39s) Loss: 1.8696 Grad: nan  LR: 0.00000329
# Epoch: [2][1640/3461] Elapsed 5m 56s (remain 6m 35s) Loss: 1.8693 Grad: nan  LR: 0.00000322
# Epoch: [2][1660/3461] Elapsed 6m 0s (remain 6m 30s) Loss: 1.8693 Grad: nan  LR: 0.00000316
# Epoch: [2][1680/3461] Elapsed 6m 4s (remain 6m 26s) Loss: 1.8695 Grad: nan  LR: 0.00000309
# Epoch: [2][1700/3461] Elapsed 6m 9s (remain 6m 22s) Loss: 1.8698 Grad: nan  LR: 0.00000302
# Epoch: [2][1720/3461] Elapsed 6m 13s (remain 6m 17s) Loss: 1.8696 Grad: nan  LR: 0.00000296
# Epoch: [2][1740/3461] Elapsed 6m 17s (remain 6m 13s) Loss: 1.8697 Grad: nan  LR: 0.00000290
# Epoch: [2][1760/3461] Elapsed 6m 22s (remain 6m 8s) Loss: 1.8699 Grad: nan  LR: 0.00000283
# Epoch: [2][1780/3461] Elapsed 6m 26s (remain 6m 4s) Loss: 1.8702 Grad: nan  LR: 0.00000277
# Epoch: [2][1800/3461] Elapsed 6m 30s (remain 6m 0s) Loss: 1.8699 Grad: nan  LR: 0.00000271
# Epoch: [2][1820/3461] Elapsed 6m 35s (remain 5m 55s) Loss: 1.8700 Grad: nan  LR: 0.00000264
# Epoch: [2][1840/3461] Elapsed 6m 39s (remain 5m 51s) Loss: 1.8694 Grad: nan  LR: 0.00000258
# Epoch: [2][1860/3461] Elapsed 6m 44s (remain 5m 47s) Loss: 1.8691 Grad: nan  LR: 0.00000252
# Epoch: [2][1880/3461] Elapsed 6m 48s (remain 5m 43s) Loss: 1.8698 Grad: nan  LR: 0.00000246
# Epoch: [2][1900/3461] Elapsed 6m 52s (remain 5m 38s) Loss: 1.8699 Grad: nan  LR: 0.00000240
# Epoch: [2][1920/3461] Elapsed 6m 56s (remain 5m 34s) Loss: 1.8704 Grad: nan  LR: 0.00000234
# Epoch: [2][1940/3461] Elapsed 7m 1s (remain 5m 29s) Loss: 1.8703 Grad: nan  LR: 0.00000229
# Epoch: [2][1960/3461] Elapsed 7m 5s (remain 5m 25s) Loss: 1.8701 Grad: nan  LR: 0.00000223
# Epoch: [2][1980/3461] Elapsed 7m 9s (remain 5m 21s) Loss: 1.8702 Grad: nan  LR: 0.00000217
# Epoch: [2][2000/3461] Elapsed 7m 14s (remain 5m 16s) Loss: 1.8698 Grad: nan  LR: 0.00000212
# Epoch: [2][2020/3461] Elapsed 7m 18s (remain 5m 12s) Loss: 1.8699 Grad: nan  LR: 0.00000206
# Epoch: [2][2040/3461] Elapsed 7m 22s (remain 5m 7s) Loss: 1.8702 Grad: nan  LR: 0.00000201
# Epoch: [2][2060/3461] Elapsed 7m 26s (remain 5m 3s) Loss: 1.8701 Grad: nan  LR: 0.00000195
# Epoch: [2][2080/3461] Elapsed 7m 31s (remain 4m 59s) Loss: 1.8704 Grad: nan  LR: 0.00000190
# Epoch: [2][2100/3461] Elapsed 7m 35s (remain 4m 54s) Loss: 1.8705 Grad: nan  LR: 0.00000185
# Epoch: [2][2120/3461] Elapsed 7m 39s (remain 4m 50s) Loss: 1.8703 Grad: nan  LR: 0.00000179
# Epoch: [2][2140/3461] Elapsed 7m 44s (remain 4m 46s) Loss: 1.8702 Grad: nan  LR: 0.00000174
# Epoch: [2][2160/3461] Elapsed 7m 48s (remain 4m 41s) Loss: 1.8702 Grad: nan  LR: 0.00000169
# Epoch: [2][2180/3461] Elapsed 7m 52s (remain 4m 37s) Loss: 1.8702 Grad: nan  LR: 0.00000164
# Epoch: [2][2200/3461] Elapsed 7m 57s (remain 4m 33s) Loss: 1.8703 Grad: nan  LR: 0.00000159
# Epoch: [2][2220/3461] Elapsed 8m 1s (remain 4m 28s) Loss: 1.8702 Grad: nan  LR: 0.00000154
# Epoch: [2][2240/3461] Elapsed 8m 6s (remain 4m 24s) Loss: 1.8702 Grad: nan  LR: 0.00000149
# Epoch: [2][2260/3461] Elapsed 8m 10s (remain 4m 20s) Loss: 1.8700 Grad: nan  LR: 0.00000145
# Epoch: [2][2280/3461] Elapsed 8m 14s (remain 4m 15s) Loss: 1.8700 Grad: nan  LR: 0.00000140
# Epoch: [2][2300/3461] Elapsed 8m 18s (remain 4m 11s) Loss: 1.8698 Grad: nan  LR: 0.00000135
# Epoch: [2][2320/3461] Elapsed 8m 23s (remain 4m 7s) Loss: 1.8703 Grad: nan  LR: 0.00000131
# Epoch: [2][2340/3461] Elapsed 8m 27s (remain 4m 2s) Loss: 1.8704 Grad: nan  LR: 0.00000126
# Epoch: [2][2360/3461] Elapsed 8m 32s (remain 3m 58s) Loss: 1.8704 Grad: nan  LR: 0.00000122
# Epoch: [2][2380/3461] Elapsed 8m 36s (remain 3m 54s) Loss: 1.8706 Grad: nan  LR: 0.00000118
# Epoch: [2][2400/3461] Elapsed 8m 40s (remain 3m 49s) Loss: 1.8704 Grad: nan  LR: 0.00000114
# Epoch: [2][2420/3461] Elapsed 8m 44s (remain 3m 45s) Loss: 1.8704 Grad: nan  LR: 0.00000109
# Epoch: [2][2440/3461] Elapsed 8m 49s (remain 3m 41s) Loss: 1.8705 Grad: nan  LR: 0.00000105
# Epoch: [2][2460/3461] Elapsed 8m 53s (remain 3m 36s) Loss: 1.8705 Grad: nan  LR: 0.00000101
# Epoch: [2][2480/3461] Elapsed 8m 57s (remain 3m 32s) Loss: 1.8703 Grad: nan  LR: 0.00000097
# Epoch: [2][2500/3461] Elapsed 9m 2s (remain 3m 28s) Loss: 1.8706 Grad: nan  LR: 0.00000093
# Epoch: [2][2520/3461] Elapsed 9m 6s (remain 3m 23s) Loss: 1.8704 Grad: nan  LR: 0.00000090
# Epoch: [2][2540/3461] Elapsed 9m 10s (remain 3m 19s) Loss: 1.8701 Grad: nan  LR: 0.00000086
# Epoch: [2][2560/3461] Elapsed 9m 15s (remain 3m 15s) Loss: 1.8700 Grad: nan  LR: 0.00000082
# Epoch: [2][2580/3461] Elapsed 9m 19s (remain 3m 10s) Loss: 1.8699 Grad: nan  LR: 0.00000079
# Epoch: [2][2600/3461] Elapsed 9m 23s (remain 3m 6s) Loss: 1.8699 Grad: nan  LR: 0.00000075
# Epoch: [2][2620/3461] Elapsed 9m 28s (remain 3m 2s) Loss: 1.8702 Grad: nan  LR: 0.00000072
# Epoch: [2][2640/3461] Elapsed 9m 32s (remain 2m 57s) Loss: 1.8702 Grad: nan  LR: 0.00000068
# Epoch: [2][2660/3461] Elapsed 9m 36s (remain 2m 53s) Loss: 1.8702 Grad: nan  LR: 0.00000065
# Epoch: [2][2680/3461] Elapsed 9m 41s (remain 2m 49s) Loss: 1.8700 Grad: nan  LR: 0.00000062
# Epoch: [2][2700/3461] Elapsed 9m 45s (remain 2m 44s) Loss: 1.8702 Grad: nan  LR: 0.00000059
# Epoch: [2][2720/3461] Elapsed 9m 49s (remain 2m 40s) Loss: 1.8703 Grad: nan  LR: 0.00000056
# Epoch: [2][2740/3461] Elapsed 9m 54s (remain 2m 36s) Loss: 1.8698 Grad: nan  LR: 0.00000053
# Epoch: [2][2760/3461] Elapsed 9m 58s (remain 2m 31s) Loss: 1.8697 Grad: nan  LR: 0.00000050
# Epoch: [2][2780/3461] Elapsed 10m 2s (remain 2m 27s) Loss: 1.8694 Grad: nan  LR: 0.00000047
# Epoch: [2][2800/3461] Elapsed 10m 6s (remain 2m 23s) Loss: 1.8690 Grad: nan  LR: 0.00000045
# Epoch: [2][2820/3461] Elapsed 10m 11s (remain 2m 18s) Loss: 1.8690 Grad: nan  LR: 0.00000042
# Epoch: [2][2840/3461] Elapsed 10m 15s (remain 2m 14s) Loss: 1.8689 Grad: nan  LR: 0.00000039
# Epoch: [2][2860/3461] Elapsed 10m 20s (remain 2m 10s) Loss: 1.8687 Grad: nan  LR: 0.00000037
# Epoch: [2][2880/3461] Elapsed 10m 24s (remain 2m 5s) Loss: 1.8688 Grad: nan  LR: 0.00000034
# Epoch: [2][2900/3461] Elapsed 10m 28s (remain 2m 1s) Loss: 1.8689 Grad: nan  LR: 0.00000032
# Epoch: [2][2920/3461] Elapsed 10m 33s (remain 1m 57s) Loss: 1.8689 Grad: nan  LR: 0.00000030
# Epoch: [2][2940/3461] Elapsed 10m 37s (remain 1m 52s) Loss: 1.8689 Grad: nan  LR: 0.00000028
# Epoch: [2][2960/3461] Elapsed 10m 41s (remain 1m 48s) Loss: 1.8690 Grad: nan  LR: 0.00000026
# Epoch: [2][2980/3461] Elapsed 10m 46s (remain 1m 44s) Loss: 1.8694 Grad: nan  LR: 0.00000024
# Epoch: [2][3000/3461] Elapsed 10m 50s (remain 1m 39s) Loss: 1.8692 Grad: nan  LR: 0.00000022
# Epoch: [2][3020/3461] Elapsed 10m 55s (remain 1m 35s) Loss: 1.8693 Grad: nan  LR: 0.00000020
# Epoch: [2][3040/3461] Elapsed 10m 59s (remain 1m 31s) Loss: 1.8692 Grad: nan  LR: 0.00000018
# Epoch: [2][3060/3461] Elapsed 11m 3s (remain 1m 26s) Loss: 1.8691 Grad: nan  LR: 0.00000016
# Epoch: [2][3080/3461] Elapsed 11m 8s (remain 1m 22s) Loss: 1.8692 Grad: nan  LR: 0.00000015
# Epoch: [2][3100/3461] Elapsed 11m 12s (remain 1m 18s) Loss: 1.8693 Grad: nan  LR: 0.00000013
# Epoch: [2][3120/3461] Elapsed 11m 16s (remain 1m 13s) Loss: 1.8694 Grad: nan  LR: 0.00000012
# Epoch: [2][3140/3461] Elapsed 11m 20s (remain 1m 9s) Loss: 1.8694 Grad: nan  LR: 0.00000011
# Epoch: [2][3160/3461] Elapsed 11m 25s (remain 1m 5s) Loss: 1.8695 Grad: nan  LR: 0.00000009
# Epoch: [2][3180/3461] Elapsed 11m 29s (remain 1m 0s) Loss: 1.8692 Grad: nan  LR: 0.00000008
# Epoch: [2][3200/3461] Elapsed 11m 33s (remain 0m 56s) Loss: 1.8694 Grad: nan  LR: 0.00000007
# Epoch: [2][3220/3461] Elapsed 11m 38s (remain 0m 52s) Loss: 1.8695 Grad: nan  LR: 0.00000006
# Epoch: [2][3240/3461] Elapsed 11m 42s (remain 0m 47s) Loss: 1.8696 Grad: nan  LR: 0.00000005
# Epoch: [2][3260/3461] Elapsed 11m 47s (remain 0m 43s) Loss: 1.8699 Grad: nan  LR: 0.00000004
# Epoch: [2][3280/3461] Elapsed 11m 51s (remain 0m 39s) Loss: 1.8698 Grad: nan  LR: 0.00000003
# Epoch: [2][3300/3461] Elapsed 11m 55s (remain 0m 34s) Loss: 1.8695 Grad: nan  LR: 0.00000003
# Epoch: [2][3320/3461] Elapsed 12m 0s (remain 0m 30s) Loss: 1.8696 Grad: nan  LR: 0.00000002
# Epoch: [2][3340/3461] Elapsed 12m 4s (remain 0m 26s) Loss: 1.8693 Grad: nan  LR: 0.00000001
# Epoch: [2][3360/3461] Elapsed 12m 8s (remain 0m 21s) Loss: 1.8695 Grad: nan  LR: 0.00000001
# Epoch: [2][3380/3461] Elapsed 12m 13s (remain 0m 17s) Loss: 1.8696 Grad: nan  LR: 0.00000001
# Epoch: [2][3400/3461] Elapsed 12m 17s (remain 0m 13s) Loss: 1.8696 Grad: nan  LR: 0.00000000
# Epoch: [2][3420/3461] Elapsed 12m 21s (remain 0m 8s) Loss: 1.8695 Grad: nan  LR: 0.00000000
# Epoch: [2][3440/3461] Elapsed 12m 26s (remain 0m 4s) Loss: 1.8692 Grad: nan  LR: 0.00000000
# Epoch: [2][3460/3461] Elapsed 12m 30s (remain 0m 0s) Loss: 1.8690 Grad: nan  LR: 0.00000000
# Validation:   0%|          | 0/866 [00:00<?, ?valid_batch/s]
# EVAL: [0/866] Elapsed 0m 0s (remain 1m 6s) Loss: 1.8455
# EVAL: [20/866] Elapsed 0m 1s (remain 0m 51s) Loss: 1.8804
# EVAL: [40/866] Elapsed 0m 2s (remain 0m 50s) Loss: 1.8857
# EVAL: [60/866] Elapsed 0m 3s (remain 0m 49s) Loss: 1.8786
# EVAL: [80/866] Elapsed 0m 4s (remain 0m 48s) Loss: 1.8705
# EVAL: [100/866] Elapsed 0m 6s (remain 0m 46s) Loss: 1.8729
# EVAL: [120/866] Elapsed 0m 7s (remain 0m 45s) Loss: 1.8750
# EVAL: [140/866] Elapsed 0m 8s (remain 0m 44s) Loss: 1.8746
# EVAL: [160/866] Elapsed 0m 9s (remain 0m 42s) Loss: 1.8788
# EVAL: [180/866] Elapsed 0m 10s (remain 0m 41s) Loss: 1.8740
# EVAL: [200/866] Elapsed 0m 12s (remain 0m 40s) Loss: 1.8759
# EVAL: [220/866] Elapsed 0m 13s (remain 0m 39s) Loss: 1.8728
# EVAL: [240/866] Elapsed 0m 14s (remain 0m 37s) Loss: 1.8748
# EVAL: [260/866] Elapsed 0m 15s (remain 0m 36s) Loss: 1.8717
# EVAL: [280/866] Elapsed 0m 17s (remain 0m 35s) Loss: 1.8739
# EVAL: [300/866] Elapsed 0m 18s (remain 0m 34s) Loss: 1.8727
# EVAL: [320/866] Elapsed 0m 19s (remain 0m 33s) Loss: 1.8733
# EVAL: [340/866] Elapsed 0m 20s (remain 0m 32s) Loss: 1.8723
# EVAL: [360/866] Elapsed 0m 21s (remain 0m 30s) Loss: 1.8730
# EVAL: [380/866] Elapsed 0m 23s (remain 0m 29s) Loss: 1.8723
# EVAL: [400/866] Elapsed 0m 24s (remain 0m 28s) Loss: 1.8733
# EVAL: [420/866] Elapsed 0m 25s (remain 0m 27s) Loss: 1.8729
# EVAL: [440/866] Elapsed 0m 26s (remain 0m 25s) Loss: 1.8722
# EVAL: [460/866] Elapsed 0m 28s (remain 0m 24s) Loss: 1.8712
# EVAL: [480/866] Elapsed 0m 29s (remain 0m 23s) Loss: 1.8707
# EVAL: [500/866] Elapsed 0m 30s (remain 0m 22s) Loss: 1.8734
# EVAL: [520/866] Elapsed 0m 31s (remain 0m 20s) Loss: 1.8724
# EVAL: [540/866] Elapsed 0m 32s (remain 0m 19s) Loss: 1.8716
# EVAL: [560/866] Elapsed 0m 34s (remain 0m 18s) Loss: 1.8706
# EVAL: [580/866] Elapsed 0m 35s (remain 0m 17s) Loss: 1.8699
# EVAL: [600/866] Elapsed 0m 36s (remain 0m 16s) Loss: 1.8690
# EVAL: [620/866] Elapsed 0m 37s (remain 0m 14s) Loss: 1.8680
# EVAL: [640/866] Elapsed 0m 38s (remain 0m 13s) Loss: 1.8682
# EVAL: [660/866] Elapsed 0m 40s (remain 0m 12s) Loss: 1.8668
# EVAL: [680/866] Elapsed 0m 41s (remain 0m 11s) Loss: 1.8665
# EVAL: [700/866] Elapsed 0m 42s (remain 0m 10s) Loss: 1.8650
# EVAL: [720/866] Elapsed 0m 43s (remain 0m 8s) Loss: 1.8635
# EVAL: [740/866] Elapsed 0m 45s (remain 0m 7s) Loss: 1.8638
# EVAL: [760/866] Elapsed 0m 46s (remain 0m 6s) Loss: 1.8623
# EVAL: [780/866] Elapsed 0m 47s (remain 0m 5s) Loss: 1.8627
# EVAL: [800/866] Elapsed 0m 48s (remain 0m 3s) Loss: 1.8623
# EVAL: [820/866] Elapsed 0m 49s (remain 0m 2s) Loss: 1.8623
# EVAL: [840/866] Elapsed 0m 51s (remain 0m 1s) Loss: 1.8621
# EVAL: [860/866] Elapsed 0m 52s (remain 0m 0s) Loss: 1.8647
# Epoch 2 - avg_train_loss: 1.8690  avg_val_loss: 1.8663  time: 803s
# Epoch 2 - Score: 0.0763
# EVAL: [865/866] Elapsed 0m 52s (remain 0m 0s) Loss: 1.8663
# ========== Fold: 0 result ==========
# Score: 0.0763
# ========== Fold: 1 training ==========
# Train:   0%|          | 0/3461 [00:00<?, ?train_batch/s]
# Epoch: [1][0/3461] Elapsed 0m 0s (remain 13m 52s) Loss: 1.7622 Grad: inf  LR: 0.00002000
# Epoch: [1][20/3461] Elapsed 0m 4s (remain 11m 55s) Loss: 1.6464 Grad: nan  LR: 0.00002000
# Epoch: [1][40/3461] Elapsed 0m 8s (remain 12m 6s) Loss: 1.6510 Grad: nan  LR: 0.00002000
# Epoch: [1][60/3461] Elapsed 0m 12s (remain 12m 3s) Loss: 1.6759 Grad: nan  LR: 0.00002000
# Epoch: [1][80/3461] Elapsed 0m 17s (remain 11m 57s) Loss: 1.6634 Grad: nan  LR: 0.00001999
# Epoch: [1][100/3461] Elapsed 0m 21s (remain 11m 56s) Loss: 1.6571 Grad: nan  LR: 0.00001999
# Epoch: [1][120/3461] Elapsed 0m 25s (remain 11m 56s) Loss: 1.6602 Grad: nan  LR: 0.00001998
# Epoch: [1][140/3461] Elapsed 0m 30s (remain 11m 56s) Loss: 1.6569 Grad: nan  LR: 0.00001998
# Epoch: [1][160/3461] Elapsed 0m 34s (remain 11m 53s) Loss: 1.6536 Grad: nan  LR: 0.00001997
# Epoch: [1][180/3461] Elapsed 0m 39s (remain 11m 46s) Loss: 1.6531 Grad: nan  LR: 0.00001997
# Epoch: [1][200/3461] Elapsed 0m 43s (remain 11m 44s) Loss: 1.6534 Grad: nan  LR: 0.00001996
# Epoch: [1][220/3461] Elapsed 0m 47s (remain 11m 38s) Loss: 1.6501 Grad: nan  LR: 0.00001995
# Epoch: [1][240/3461] Elapsed 0m 52s (remain 11m 35s) Loss: 1.6550 Grad: nan  LR: 0.00001994
# Epoch: [1][260/3461] Elapsed 0m 56s (remain 11m 32s) Loss: 1.6589 Grad: nan  LR: 0.00001993
# Epoch: [1][280/3461] Elapsed 1m 0s (remain 11m 29s) Loss: 1.6577 Grad: nan  LR: 0.00001992
# Epoch: [1][300/3461] Elapsed 1m 5s (remain 11m 24s) Loss: 1.6537 Grad: nan  LR: 0.00001991
# Epoch: [1][320/3461] Elapsed 1m 9s (remain 11m 20s) Loss: 1.6520 Grad: nan  LR: 0.00001989
# Epoch: [1][340/3461] Elapsed 1m 13s (remain 11m 15s) Loss: 1.6506 Grad: nan  LR: 0.00001988
# Epoch: [1][360/3461] Elapsed 1m 18s (remain 11m 11s) Loss: 1.6515 Grad: nan  LR: 0.00001987
# Epoch: [1][380/3461] Elapsed 1m 22s (remain 11m 6s) Loss: 1.6510 Grad: nan  LR: 0.00001985
# Epoch: [1][400/3461] Elapsed 1m 26s (remain 11m 3s) Loss: 1.6496 Grad: nan  LR: 0.00001983
# Epoch: [1][420/3461] Elapsed 1m 31s (remain 10m 58s) Loss: 1.6491 Grad: nan  LR: 0.00001982
# Epoch: [1][440/3461] Elapsed 1m 35s (remain 10m 54s) Loss: 1.6508 Grad: nan  LR: 0.00001980
# Epoch: [1][460/3461] Elapsed 1m 39s (remain 10m 49s) Loss: 1.6507 Grad: nan  LR: 0.00001978
# Epoch: [1][480/3461] Elapsed 1m 44s (remain 10m 45s) Loss: 1.6521 Grad: nan  LR: 0.00001976
# Epoch: [1][500/3461] Elapsed 1m 48s (remain 10m 41s) Loss: 1.6529 Grad: nan  LR: 0.00001974
# Epoch: [1][520/3461] Elapsed 1m 52s (remain 10m 36s) Loss: 1.6519 Grad: nan  LR: 0.00001972
# Epoch: [1][540/3461] Elapsed 1m 57s (remain 10m 33s) Loss: 1.6522 Grad: nan  LR: 0.00001970
# Epoch: [1][560/3461] Elapsed 2m 1s (remain 10m 28s) Loss: 1.6517 Grad: nan  LR: 0.00001968
# Epoch: [1][580/3461] Elapsed 2m 6s (remain 10m 24s) Loss: 1.6524 Grad: nan  LR: 0.00001965
# Epoch: [1][600/3461] Elapsed 2m 10s (remain 10m 21s) Loss: 1.6501 Grad: nan  LR: 0.00001963
# Epoch: [1][620/3461] Elapsed 2m 14s (remain 10m 17s) Loss: 1.6502 Grad: nan  LR: 0.00001961
# Epoch: [1][640/3461] Elapsed 2m 19s (remain 10m 13s) Loss: 1.6497 Grad: nan  LR: 0.00001958
# Epoch: [1][660/3461] Elapsed 2m 23s (remain 10m 9s) Loss: 1.6517 Grad: nan  LR: 0.00001955
# Epoch: [1][680/3461] Elapsed 2m 27s (remain 10m 4s) Loss: 1.6496 Grad: nan  LR: 0.00001953
# Epoch: [1][700/3461] Elapsed 2m 32s (remain 9m 59s) Loss: 1.6481 Grad: nan  LR: 0.00001950
# Epoch: [1][720/3461] Elapsed 2m 36s (remain 9m 55s) Loss: 1.6482 Grad: nan  LR: 0.00001947
# Epoch: [1][740/3461] Elapsed 2m 41s (remain 9m 51s) Loss: 1.6474 Grad: nan  LR: 0.00001944
# Epoch: [1][760/3461] Elapsed 2m 45s (remain 9m 46s) Loss: 1.6477 Grad: nan  LR: 0.00001941
# Epoch: [1][780/3461] Elapsed 2m 49s (remain 9m 42s) Loss: 1.6480 Grad: nan  LR: 0.00001938
# Epoch: [1][800/3461] Elapsed 2m 54s (remain 9m 37s) Loss: 1.6471 Grad: nan  LR: 0.00001935
# Epoch: [1][820/3461] Elapsed 2m 58s (remain 9m 33s) Loss: 1.6468 Grad: nan  LR: 0.00001931
# Epoch: [1][840/3461] Elapsed 3m 2s (remain 9m 29s) Loss: 1.6471 Grad: nan  LR: 0.00001928
# Epoch: [1][860/3461] Elapsed 3m 7s (remain 9m 24s) Loss: 1.6479 Grad: nan  LR: 0.00001925
# Epoch: [1][880/3461] Elapsed 3m 11s (remain 9m 20s) Loss: 1.6468 Grad: nan  LR: 0.00001921
# Epoch: [1][900/3461] Elapsed 3m 15s (remain 9m 15s) Loss: 1.6475 Grad: nan  LR: 0.00001918
# Epoch: [1][920/3461] Elapsed 3m 19s (remain 9m 11s) Loss: 1.6460 Grad: nan  LR: 0.00001914
# Epoch: [1][940/3461] Elapsed 3m 24s (remain 9m 7s) Loss: 1.6458 Grad: nan  LR: 0.00001910
# Epoch: [1][960/3461] Elapsed 3m 28s (remain 9m 2s) Loss: 1.6461 Grad: nan  LR: 0.00001906
# Epoch: [1][980/3461] Elapsed 3m 32s (remain 8m 58s) Loss: 1.6482 Grad: nan  LR: 0.00001903
# Epoch: [1][1000/3461] Elapsed 3m 37s (remain 8m 53s) Loss: 1.6488 Grad: nan  LR: 0.00001899
# Epoch: [1][1020/3461] Elapsed 3m 41s (remain 8m 49s) Loss: 1.6487 Grad: nan  LR: 0.00001895
# Epoch: [1][1040/3461] Elapsed 3m 45s (remain 8m 44s) Loss: 1.6488 Grad: nan  LR: 0.00001890
# Epoch: [1][1060/3461] Elapsed 3m 50s (remain 8m 40s) Loss: 1.6487 Grad: nan  LR: 0.00001886
# Epoch: [1][1080/3461] Elapsed 3m 54s (remain 8m 36s) Loss: 1.6497 Grad: nan  LR: 0.00001882
# Epoch: [1][1100/3461] Elapsed 3m 58s (remain 8m 32s) Loss: 1.6496 Grad: nan  LR: 0.00001878
# Epoch: [1][1120/3461] Elapsed 4m 3s (remain 8m 28s) Loss: 1.6498 Grad: nan  LR: 0.00001873
# Epoch: [1][1140/3461] Elapsed 4m 7s (remain 8m 23s) Loss: 1.6494 Grad: nan  LR: 0.00001869
# Epoch: [1][1160/3461] Elapsed 4m 12s (remain 8m 19s) Loss: 1.6490 Grad: nan  LR: 0.00001864
# Epoch: [1][1180/3461] Elapsed 4m 16s (remain 8m 15s) Loss: 1.6493 Grad: nan  LR: 0.00001860
# Epoch: [1][1200/3461] Elapsed 4m 20s (remain 8m 11s) Loss: 1.6498 Grad: nan  LR: 0.00001855
# Epoch: [1][1220/3461] Elapsed 4m 25s (remain 8m 6s) Loss: 1.6500 Grad: nan  LR: 0.00001850
# Epoch: [1][1240/3461] Elapsed 4m 29s (remain 8m 2s) Loss: 1.6501 Grad: nan  LR: 0.00001846
# Epoch: [1][1260/3461] Elapsed 4m 34s (remain 7m 58s) Loss: 1.6497 Grad: nan  LR: 0.00001841
# Epoch: [1][1280/3461] Elapsed 4m 38s (remain 7m 53s) Loss: 1.6494 Grad: nan  LR: 0.00001836
# Epoch: [1][1300/3461] Elapsed 4m 42s (remain 7m 49s) Loss: 1.6504 Grad: nan  LR: 0.00001831
# Epoch: [1][1320/3461] Elapsed 4m 47s (remain 7m 45s) Loss: 1.6502 Grad: nan  LR: 0.00001826
# Epoch: [1][1340/3461] Elapsed 4m 51s (remain 7m 40s) Loss: 1.6505 Grad: nan  LR: 0.00001820
# Epoch: [1][1360/3461] Elapsed 4m 55s (remain 7m 36s) Loss: 1.6508 Grad: nan  LR: 0.00001815
# Epoch: [1][1380/3461] Elapsed 5m 0s (remain 7m 32s) Loss: 1.6504 Grad: nan  LR: 0.00001810
# Epoch: [1][1400/3461] Elapsed 5m 4s (remain 7m 27s) Loss: 1.6508 Grad: nan  LR: 0.00001805
# Epoch: [1][1420/3461] Elapsed 5m 8s (remain 7m 23s) Loss: 1.6508 Grad: nan  LR: 0.00001799
# Epoch: [1][1440/3461] Elapsed 5m 13s (remain 7m 19s) Loss: 1.6512 Grad: nan  LR: 0.00001794
# Epoch: [1][1460/3461] Elapsed 5m 17s (remain 7m 14s) Loss: 1.6511 Grad: nan  LR: 0.00001788
# Epoch: [1][1480/3461] Elapsed 5m 22s (remain 7m 10s) Loss: 1.6512 Grad: nan  LR: 0.00001782
# Epoch: [1][1500/3461] Elapsed 5m 26s (remain 7m 6s) Loss: 1.6518 Grad: nan  LR: 0.00001777
# Epoch: [1][1520/3461] Elapsed 5m 30s (remain 7m 1s) Loss: 1.6525 Grad: nan  LR: 0.00001771
# Epoch: [1][1540/3461] Elapsed 5m 35s (remain 6m 57s) Loss: 1.6521 Grad: nan  LR: 0.00001765
# Epoch: [1][1560/3461] Elapsed 5m 39s (remain 6m 53s) Loss: 1.6521 Grad: nan  LR: 0.00001759
# Epoch: [1][1580/3461] Elapsed 5m 43s (remain 6m 49s) Loss: 1.6524 Grad: nan  LR: 0.00001753
# Epoch: [1][1600/3461] Elapsed 5m 48s (remain 6m 44s) Loss: 1.6522 Grad: nan  LR: 0.00001747
# Epoch: [1][1620/3461] Elapsed 5m 52s (remain 6m 39s) Loss: 1.6523 Grad: nan  LR: 0.00001741
# Epoch: [1][1640/3461] Elapsed 5m 56s (remain 6m 35s) Loss: 1.6529 Grad: nan  LR: 0.00001735
# Epoch: [1][1660/3461] Elapsed 6m 0s (remain 6m 31s) Loss: 1.6536 Grad: nan  LR: 0.00001729
# Epoch: [1][1680/3461] Elapsed 6m 5s (remain 6m 26s) Loss: 1.6541 Grad: nan  LR: 0.00001723
# Epoch: [1][1700/3461] Elapsed 6m 9s (remain 6m 22s) Loss: 1.6537 Grad: nan  LR: 0.00001717
# Epoch: [1][1720/3461] Elapsed 6m 14s (remain 6m 18s) Loss: 1.6532 Grad: nan  LR: 0.00001710
# Epoch: [1][1740/3461] Elapsed 6m 18s (remain 6m 13s) Loss: 1.6531 Grad: nan  LR: 0.00001704
# Epoch: [1][1760/3461] Elapsed 6m 22s (remain 6m 9s) Loss: 1.6525 Grad: nan  LR: 0.00001697
# Epoch: [1][1780/3461] Elapsed 6m 27s (remain 6m 5s) Loss: 1.6524 Grad: nan  LR: 0.00001691
# Epoch: [1][1800/3461] Elapsed 6m 31s (remain 6m 0s) Loss: 1.6525 Grad: nan  LR: 0.00001684
# Epoch: [1][1820/3461] Elapsed 6m 35s (remain 5m 56s) Loss: 1.6527 Grad: nan  LR: 0.00001677
# Epoch: [1][1840/3461] Elapsed 6m 39s (remain 5m 51s) Loss: 1.6527 Grad: nan  LR: 0.00001671
# Epoch: [1][1860/3461] Elapsed 6m 44s (remain 5m 47s) Loss: 1.6533 Grad: nan  LR: 0.00001664
# Epoch: [1][1880/3461] Elapsed 6m 48s (remain 5m 43s) Loss: 1.6534 Grad: nan  LR: 0.00001657
# Epoch: [1][1900/3461] Elapsed 6m 52s (remain 5m 38s) Loss: 1.6534 Grad: nan  LR: 0.00001650
# Epoch: [1][1920/3461] Elapsed 6m 57s (remain 5m 34s) Loss: 1.6537 Grad: nan  LR: 0.00001643
# Epoch: [1][1940/3461] Elapsed 7m 1s (remain 5m 30s) Loss: 1.6537 Grad: nan  LR: 0.00001636
# ...
# Epoch: [2][700/3461] Elapsed 2m 32s (remain 9m 58s) Loss: 1.6335 Grad: nan  LR: 0.00000687
# Epoch: [2][720/3461] Elapsed 2m 36s (remain 9m 53s) Loss: 1.6331 Grad: nan  LR: 0.00000679
# Epoch: [2][740/3461] Elapsed 2m 40s (remain 9m 49s) Loss: 1.6325 Grad: nan  LR: 0.00000670
# Epoch: [2][760/3461] Elapsed 2m 45s (remain 9m 45s) Loss: 1.6337 Grad: nan  LR: 0.00000662
# Epoch: [2][780/3461] Elapsed 2m 49s (remain 9m 41s) Loss: 1.6345 Grad: nan  LR: 0.00000653
# Epoch: [2][800/3461] Elapsed 2m 53s (remain 9m 37s) Loss: 1.6333 Grad: nan  LR: 0.00000645
# Epoch: [2][820/3461] Elapsed 2m 58s (remain 9m 32s) Loss: 1.6315 Grad: nan  LR: 0.00000636
# Epoch: [2][840/3461] Elapsed 3m 2s (remain 9m 27s) Loss: 1.6317 Grad: nan  LR: 0.00000628
# Epoch: [2][860/3461] Elapsed 3m 6s (remain 9m 23s) Loss: 1.6320 Grad: nan  LR: 0.00000619
# Epoch: [2][880/3461] Elapsed 3m 11s (remain 9m 19s) Loss: 1.6314 Grad: nan  LR: 0.00000611
# Epoch: [2][900/3461] Elapsed 3m 15s (remain 9m 15s) Loss: 1.6314 Grad: nan  LR: 0.00000603
# Epoch: [2][920/3461] Elapsed 3m 19s (remain 9m 11s) Loss: 1.6294 Grad: nan  LR: 0.00000594
# Epoch: [2][940/3461] Elapsed 3m 24s (remain 9m 6s) Loss: 1.6282 Grad: nan  LR: 0.00000586
# Epoch: [2][960/3461] Elapsed 3m 28s (remain 9m 2s) Loss: 1.6289 Grad: nan  LR: 0.00000578
# Epoch: [2][980/3461] Elapsed 3m 32s (remain 8m 57s) Loss: 1.6292 Grad: nan  LR: 0.00000570
# Epoch: [2][1000/3461] Elapsed 3m 37s (remain 8m 53s) Loss: 1.6281 Grad: nan  LR: 0.00000561
# Epoch: [2][1020/3461] Elapsed 3m 41s (remain 8m 49s) Loss: 1.6288 Grad: nan  LR: 0.00000553
# Epoch: [2][1040/3461] Elapsed 3m 45s (remain 8m 44s) Loss: 1.6277 Grad: nan  LR: 0.00000545
# Epoch: [2][1060/3461] Elapsed 3m 50s (remain 8m 40s) Loss: 1.6269 Grad: nan  LR: 0.00000537
# Epoch: [2][1080/3461] Elapsed 3m 54s (remain 8m 36s) Loss: 1.6268 Grad: nan  LR: 0.00000529
# Epoch: [2][1100/3461] Elapsed 3m 58s (remain 8m 31s) Loss: 1.6277 Grad: nan  LR: 0.00000521
# Epoch: [2][1120/3461] Elapsed 4m 3s (remain 8m 27s) Loss: 1.6269 Grad: nan  LR: 0.00000513
# Epoch: [2][1140/3461] Elapsed 4m 7s (remain 8m 23s) Loss: 1.6265 Grad: nan  LR: 0.00000505
# Epoch: [2][1160/3461] Elapsed 4m 12s (remain 8m 19s) Loss: 1.6264 Grad: nan  LR: 0.00000497
# Epoch: [2][1180/3461] Elapsed 4m 16s (remain 8m 15s) Loss: 1.6261 Grad: nan  LR: 0.00000490
# Epoch: [2][1200/3461] Elapsed 4m 20s (remain 8m 11s) Loss: 1.6258 Grad: nan  LR: 0.00000482
# Epoch: [2][1220/3461] Elapsed 4m 25s (remain 8m 6s) Loss: 1.6251 Grad: nan  LR: 0.00000474
# Epoch: [2][1240/3461] Elapsed 4m 29s (remain 8m 2s) Loss: 1.6252 Grad: nan  LR: 0.00000466
# Epoch: [2][1260/3461] Elapsed 4m 34s (remain 7m 58s) Loss: 1.6245 Grad: nan  LR: 0.00000459
# Epoch: [2][1280/3461] Elapsed 4m 38s (remain 7m 53s) Loss: 1.6250 Grad: nan  LR: 0.00000451
# Epoch: [2][1300/3461] Elapsed 4m 42s (remain 7m 49s) Loss: 1.6246 Grad: nan  LR: 0.00000444
# Epoch: [2][1320/3461] Elapsed 4m 47s (remain 7m 44s) Loss: 1.6243 Grad: nan  LR: 0.00000436
# Epoch: [2][1340/3461] Elapsed 4m 51s (remain 7m 40s) Loss: 1.6249 Grad: nan  LR: 0.00000429
# Epoch: [2][1360/3461] Elapsed 4m 55s (remain 7m 36s) Loss: 1.6252 Grad: nan  LR: 0.00000421
# Epoch: [2][1380/3461] Elapsed 5m 0s (remain 7m 31s) Loss: 1.6246 Grad: nan  LR: 0.00000414
# Epoch: [2][1400/3461] Elapsed 5m 4s (remain 7m 27s) Loss: 1.6254 Grad: nan  LR: 0.00000406
# Epoch: [2][1420/3461] Elapsed 5m 8s (remain 7m 23s) Loss: 1.6257 Grad: nan  LR: 0.00000399
# Epoch: [2][1440/3461] Elapsed 5m 13s (remain 7m 19s) Loss: 1.6256 Grad: nan  LR: 0.00000392
# Epoch: [2][1460/3461] Elapsed 5m 17s (remain 7m 14s) Loss: 1.6264 Grad: nan  LR: 0.00000385
# Epoch: [2][1480/3461] Elapsed 5m 21s (remain 7m 10s) Loss: 1.6267 Grad: nan  LR: 0.00000378
# Epoch: [2][1500/3461] Elapsed 5m 26s (remain 7m 5s) Loss: 1.6265 Grad: nan  LR: 0.00000370
# Epoch: [2][1520/3461] Elapsed 5m 30s (remain 7m 1s) Loss: 1.6256 Grad: nan  LR: 0.00000363
# Epoch: [2][1540/3461] Elapsed 5m 34s (remain 6m 56s) Loss: 1.6264 Grad: nan  LR: 0.00000356
# Epoch: [2][1560/3461] Elapsed 5m 39s (remain 6m 52s) Loss: 1.6260 Grad: nan  LR: 0.00000350
# Epoch: [2][1580/3461] Elapsed 5m 43s (remain 6m 48s) Loss: 1.6248 Grad: nan  LR: 0.00000343
# Epoch: [2][1600/3461] Elapsed 5m 47s (remain 6m 43s) Loss: 1.6251 Grad: nan  LR: 0.00000336
# Epoch: [2][1620/3461] Elapsed 5m 51s (remain 6m 39s) Loss: 1.6252 Grad: nan  LR: 0.00000329
# Epoch: [2][1640/3461] Elapsed 5m 56s (remain 6m 35s) Loss: 1.6247 Grad: nan  LR: 0.00000322
# Epoch: [2][1660/3461] Elapsed 6m 0s (remain 6m 30s) Loss: 1.6252 Grad: nan  LR: 0.00000316
# Epoch: [2][1680/3461] Elapsed 6m 4s (remain 6m 26s) Loss: 1.6252 Grad: nan  LR: 0.00000309
# Epoch: [2][1700/3461] Elapsed 6m 9s (remain 6m 22s) Loss: 1.6262 Grad: nan  LR: 0.00000303
# Epoch: [2][1720/3461] Elapsed 6m 13s (remain 6m 17s) Loss: 1.6260 Grad: nan  LR: 0.00000296
# Epoch: [2][1740/3461] Elapsed 6m 18s (remain 6m 13s) Loss: 1.6269 Grad: nan  LR: 0.00000290
# Epoch: [2][1760/3461] Elapsed 6m 22s (remain 6m 9s) Loss: 1.6267 Grad: nan  LR: 0.00000283
# Epoch: [2][1780/3461] Elapsed 6m 26s (remain 6m 4s) Loss: 1.6269 Grad: nan  LR: 0.00000277
# Epoch: [2][1800/3461] Elapsed 6m 31s (remain 6m 0s) Loss: 1.6276 Grad: nan  LR: 0.00000271
# Epoch: [2][1820/3461] Elapsed 6m 35s (remain 5m 56s) Loss: 1.6283 Grad: nan  LR: 0.00000265
# Epoch: [2][1840/3461] Elapsed 6m 39s (remain 5m 51s) Loss: 1.6290 Grad: nan  LR: 0.00000259
# Epoch: [2][1860/3461] Elapsed 6m 43s (remain 5m 47s) Loss: 1.6291 Grad: nan  LR: 0.00000253
# Epoch: [2][1880/3461] Elapsed 6m 48s (remain 5m 42s) Loss: 1.6297 Grad: nan  LR: 0.00000247
# Epoch: [2][1900/3461] Elapsed 6m 52s (remain 5m 38s) Loss: 1.6297 Grad: nan  LR: 0.00000241
# Epoch: [2][1920/3461] Elapsed 6m 56s (remain 5m 34s) Loss: 1.6291 Grad: nan  LR: 0.00000235
# Epoch: [2][1940/3461] Elapsed 7m 1s (remain 5m 29s) Loss: 1.6291 Grad: nan  LR: 0.00000229
# Epoch: [2][1960/3461] Elapsed 7m 5s (remain 5m 25s) Loss: 1.6292 Grad: nan  LR: 0.00000223
# Epoch: [2][1980/3461] Elapsed 7m 9s (remain 5m 21s) Loss: 1.6292 Grad: nan  LR: 0.00000217
# Epoch: [2][2000/3461] Elapsed 7m 14s (remain 5m 16s) Loss: 1.6298 Grad: nan  LR: 0.00000212
# Epoch: [2][2020/3461] Elapsed 7m 18s (remain 5m 12s) Loss: 1.6290 Grad: nan  LR: 0.00000206
# Epoch: [2][2040/3461] Elapsed 7m 23s (remain 5m 8s) Loss: 1.6285 Grad: nan  LR: 0.00000201
# Epoch: [2][2060/3461] Elapsed 7m 27s (remain 5m 3s) Loss: 1.6282 Grad: nan  LR: 0.00000195
# Epoch: [2][2080/3461] Elapsed 7m 31s (remain 4m 59s) Loss: 1.6281 Grad: nan  LR: 0.00000190
# Epoch: [2][2100/3461] Elapsed 7m 36s (remain 4m 55s) Loss: 1.6281 Grad: nan  LR: 0.00000185
# Epoch: [2][2120/3461] Elapsed 7m 40s (remain 4m 51s) Loss: 1.6282 Grad: nan  LR: 0.00000180
# Epoch: [2][2140/3461] Elapsed 7m 45s (remain 4m 46s) Loss: 1.6277 Grad: nan  LR: 0.00000174
# Epoch: [2][2160/3461] Elapsed 7m 49s (remain 4m 42s) Loss: 1.6279 Grad: nan  LR: 0.00000169
# Epoch: [2][2180/3461] Elapsed 7m 53s (remain 4m 38s) Loss: 1.6276 Grad: nan  LR: 0.00000164
# Epoch: [2][2200/3461] Elapsed 7m 58s (remain 4m 33s) Loss: 1.6272 Grad: nan  LR: 0.00000159
# Epoch: [2][2220/3461] Elapsed 8m 2s (remain 4m 29s) Loss: 1.6270 Grad: nan  LR: 0.00000154
# Epoch: [2][2240/3461] Elapsed 8m 6s (remain 4m 24s) Loss: 1.6276 Grad: nan  LR: 0.00000150
# Epoch: [2][2260/3461] Elapsed 8m 10s (remain 4m 20s) Loss: 1.6286 Grad: nan  LR: 0.00000145
# Epoch: [2][2280/3461] Elapsed 8m 15s (remain 4m 16s) Loss: 1.6285 Grad: nan  LR: 0.00000140
# Epoch: [2][2300/3461] Elapsed 8m 19s (remain 4m 11s) Loss: 1.6281 Grad: nan  LR: 0.00000136
# Epoch: [2][2320/3461] Elapsed 8m 24s (remain 4m 7s) Loss: 1.6284 Grad: nan  LR: 0.00000131
# Epoch: [2][2340/3461] Elapsed 8m 28s (remain 4m 3s) Loss: 1.6289 Grad: nan  LR: 0.00000127
# Epoch: [2][2360/3461] Elapsed 8m 32s (remain 3m 58s) Loss: 1.6291 Grad: nan  LR: 0.00000122
# Epoch: [2][2380/3461] Elapsed 8m 37s (remain 3m 54s) Loss: 1.6289 Grad: nan  LR: 0.00000118
# Epoch: [2][2400/3461] Elapsed 8m 41s (remain 3m 50s) Loss: 1.6293 Grad: nan  LR: 0.00000114
# Epoch: [2][2420/3461] Elapsed 8m 45s (remain 3m 45s) Loss: 1.6293 Grad: nan  LR: 0.00000110
# Epoch: [2][2440/3461] Elapsed 8m 49s (remain 3m 41s) Loss: 1.6295 Grad: nan  LR: 0.00000105
# Epoch: [2][2460/3461] Elapsed 8m 54s (remain 3m 37s) Loss: 1.6298 Grad: nan  LR: 0.00000101
# Epoch: [2][2480/3461] Elapsed 8m 58s (remain 3m 32s) Loss: 1.6298 Grad: nan  LR: 0.00000097
# Epoch: [2][2500/3461] Elapsed 9m 2s (remain 3m 28s) Loss: 1.6299 Grad: nan  LR: 0.00000094
# Epoch: [2][2520/3461] Elapsed 9m 7s (remain 3m 24s) Loss: 1.6296 Grad: nan  LR: 0.00000090
# Epoch: [2][2540/3461] Elapsed 9m 11s (remain 3m 19s) Loss: 1.6298 Grad: nan  LR: 0.00000086
# Epoch: [2][2560/3461] Elapsed 9m 15s (remain 3m 15s) Loss: 1.6298 Grad: nan  LR: 0.00000082
# Epoch: [2][2580/3461] Elapsed 9m 20s (remain 3m 11s) Loss: 1.6295 Grad: nan  LR: 0.00000079
# Epoch: [2][2600/3461] Elapsed 9m 24s (remain 3m 6s) Loss: 1.6296 Grad: nan  LR: 0.00000075
# Epoch: [2][2620/3461] Elapsed 9m 29s (remain 3m 2s) Loss: 1.6297 Grad: nan  LR: 0.00000072
# Epoch: [2][2640/3461] Elapsed 9m 33s (remain 2m 58s) Loss: 1.6294 Grad: nan  LR: 0.00000069
# Epoch: [2][2660/3461] Elapsed 9m 37s (remain 2m 53s) Loss: 1.6290 Grad: nan  LR: 0.00000065
# Epoch: [2][2680/3461] Elapsed 9m 42s (remain 2m 49s) Loss: 1.6292 Grad: nan  LR: 0.00000062
# Epoch: [2][2700/3461] Elapsed 9m 46s (remain 2m 44s) Loss: 1.6294 Grad: nan  LR: 0.00000059
# Epoch: [2][2720/3461] Elapsed 9m 50s (remain 2m 40s) Loss: 1.6293 Grad: nan  LR: 0.00000056
# Epoch: [2][2740/3461] Elapsed 9m 54s (remain 2m 36s) Loss: 1.6290 Grad: nan  LR: 0.00000053
# Epoch: [2][2760/3461] Elapsed 9m 59s (remain 2m 31s) Loss: 1.6289 Grad: nan  LR: 0.00000050
# Epoch: [2][2780/3461] Elapsed 10m 3s (remain 2m 27s) Loss: 1.6284 Grad: nan  LR: 0.00000047
# Epoch: [2][2800/3461] Elapsed 10m 7s (remain 2m 23s) Loss: 1.6284 Grad: nan  LR: 0.00000045
# Epoch: [2][2820/3461] Elapsed 10m 12s (remain 2m 18s) Loss: 1.6284 Grad: nan  LR: 0.00000042
# Epoch: [2][2840/3461] Elapsed 10m 16s (remain 2m 14s) Loss: 1.6284 Grad: nan  LR: 0.00000039
# Epoch: [2][2860/3461] Elapsed 10m 20s (remain 2m 10s) Loss: 1.6284 Grad: nan  LR: 0.00000037
# Epoch: [2][2880/3461] Elapsed 10m 25s (remain 2m 5s) Loss: 1.6280 Grad: nan  LR: 0.00000035
# Epoch: [2][2900/3461] Elapsed 10m 29s (remain 2m 1s) Loss: 1.6278 Grad: nan  LR: 0.00000032
# Epoch: [2][2920/3461] Elapsed 10m 34s (remain 1m 57s) Loss: 1.6279 Grad: nan  LR: 0.00000030
# Epoch: [2][2940/3461] Elapsed 10m 38s (remain 1m 52s) Loss: 1.6282 Grad: nan  LR: 0.00000028
# Epoch: [2][2960/3461] Elapsed 10m 42s (remain 1m 48s) Loss: 1.6281 Grad: nan  LR: 0.00000026
# Epoch: [2][2980/3461] Elapsed 10m 47s (remain 1m 44s) Loss: 1.6281 Grad: nan  LR: 0.00000024
# Epoch: [2][3000/3461] Elapsed 10m 51s (remain 1m 39s) Loss: 1.6281 Grad: nan  LR: 0.00000022
# Epoch: [2][3020/3461] Elapsed 10m 55s (remain 1m 35s) Loss: 1.6285 Grad: nan  LR: 0.00000020
# Epoch: [2][3040/3461] Elapsed 10m 59s (remain 1m 31s) Loss: 1.6284 Grad: nan  LR: 0.00000018
# Epoch: [2][3060/3461] Elapsed 11m 4s (remain 1m 26s) Loss: 1.6285 Grad: nan  LR: 0.00000017
# Epoch: [2][3080/3461] Elapsed 11m 8s (remain 1m 22s) Loss: 1.6286 Grad: nan  LR: 0.00000015
# Epoch: [2][3100/3461] Elapsed 11m 12s (remain 1m 18s) Loss: 1.6286 Grad: nan  LR: 0.00000013
# Epoch: [2][3120/3461] Elapsed 11m 17s (remain 1m 13s) Loss: 1.6288 Grad: nan  LR: 0.00000012
# Epoch: [2][3140/3461] Elapsed 11m 21s (remain 1m 9s) Loss: 1.6289 Grad: nan  LR: 0.00000011
# Epoch: [2][3160/3461] Elapsed 11m 25s (remain 1m 5s) Loss: 1.6292 Grad: nan  LR: 0.00000009
# Epoch: [2][3180/3461] Elapsed 11m 30s (remain 1m 0s) Loss: 1.6293 Grad: nan  LR: 0.00000008
# Epoch: [2][3200/3461] Elapsed 11m 34s (remain 0m 56s) Loss: 1.6294 Grad: nan  LR: 0.00000007
# Epoch: [2][3220/3461] Elapsed 11m 39s (remain 0m 52s) Loss: 1.6292 Grad: nan  LR: 0.00000006
# Epoch: [2][3240/3461] Elapsed 11m 43s (remain 0m 47s) Loss: 1.6292 Grad: nan  LR: 0.00000005
# Epoch: [2][3260/3461] Elapsed 11m 47s (remain 0m 43s) Loss: 1.6299 Grad: nan  LR: 0.00000004
# Epoch: [2][3280/3461] Elapsed 11m 52s (remain 0m 39s) Loss: 1.6298 Grad: nan  LR: 0.00000003
# Epoch: [2][3300/3461] Elapsed 11m 56s (remain 0m 34s) Loss: 1.6301 Grad: nan  LR: 0.00000003
# Epoch: [2][3320/3461] Elapsed 12m 0s (remain 0m 30s) Loss: 1.6299 Grad: nan  LR: 0.00000002
# Epoch: [2][3340/3461] Elapsed 12m 5s (remain 0m 26s) Loss: 1.6299 Grad: nan  LR: 0.00000002
# Epoch: [2][3360/3461] Elapsed 12m 9s (remain 0m 21s) Loss: 1.6297 Grad: nan  LR: 0.00000001
# Epoch: [2][3380/3461] Elapsed 12m 13s (remain 0m 17s) Loss: 1.6301 Grad: nan  LR: 0.00000001
# Epoch: [2][3400/3461] Elapsed 12m 18s (remain 0m 13s) Loss: 1.6299 Grad: nan  LR: 0.00000000
# Epoch: [2][3420/3461] Elapsed 12m 22s (remain 0m 8s) Loss: 1.6296 Grad: nan  LR: 0.00000000
# Epoch: [2][3440/3461] Elapsed 12m 26s (remain 0m 4s) Loss: 1.6294 Grad: nan  LR: 0.00000000
# Epoch: [2][3460/3461] Elapsed 12m 31s (remain 0m 0s) Loss: 1.6290 Grad: nan  LR: 0.00000000
# Validation:   0%|          | 0/866 [00:00<?, ?valid_batch/s]
# EVAL: [0/866] Elapsed 0m 0s (remain 1m 10s) Loss: 1.7488
# EVAL: [20/866] Elapsed 0m 1s (remain 0m 53s) Loss: 1.5532
# EVAL: [40/866] Elapsed 0m 2s (remain 0m 51s) Loss: 1.5821
# EVAL: [60/866] Elapsed 0m 3s (remain 0m 49s) Loss: 1.5704
# EVAL: [80/866] Elapsed 0m 5s (remain 0m 48s) Loss: 1.5926
# EVAL: [100/866] Elapsed 0m 6s (remain 0m 47s) Loss: 1.6081
# EVAL: [120/866] Elapsed 0m 7s (remain 0m 45s) Loss: 1.6160
# EVAL: [140/866] Elapsed 0m 8s (remain 0m 44s) Loss: 1.6185
# EVAL: [160/866] Elapsed 0m 9s (remain 0m 43s) Loss: 1.6194
# EVAL: [180/866] Elapsed 0m 11s (remain 0m 41s) Loss: 1.6221
# EVAL: [200/866] Elapsed 0m 12s (remain 0m 40s) Loss: 1.6196
# EVAL: [220/866] Elapsed 0m 13s (remain 0m 39s) Loss: 1.6261
# EVAL: [240/866] Elapsed 0m 14s (remain 0m 38s) Loss: 1.6269
# EVAL: [260/866] Elapsed 0m 15s (remain 0m 36s) Loss: 1.6304
# EVAL: [280/866] Elapsed 0m 17s (remain 0m 35s) Loss: 1.6301
# EVAL: [300/866] Elapsed 0m 18s (remain 0m 34s) Loss: 1.6315
# EVAL: [320/866] Elapsed 0m 19s (remain 0m 33s) Loss: 1.6346
# EVAL: [340/866] Elapsed 0m 20s (remain 0m 32s) Loss: 1.6367
# EVAL: [360/866] Elapsed 0m 22s (remain 0m 30s) Loss: 1.6372
# EVAL: [380/866] Elapsed 0m 23s (remain 0m 29s) Loss: 1.6370
# EVAL: [400/866] Elapsed 0m 24s (remain 0m 28s) Loss: 1.6378
# EVAL: [420/866] Elapsed 0m 25s (remain 0m 27s) Loss: 1.6375
# EVAL: [440/866] Elapsed 0m 26s (remain 0m 25s) Loss: 1.6341
# EVAL: [460/866] Elapsed 0m 28s (remain 0m 24s) Loss: 1.6345
# EVAL: [480/866] Elapsed 0m 29s (remain 0m 23s) Loss: 1.6342
# EVAL: [500/866] Elapsed 0m 30s (remain 0m 22s) Loss: 1.6333
# EVAL: [520/866] Elapsed 0m 31s (remain 0m 21s) Loss: 1.6317
# EVAL: [540/866] Elapsed 0m 32s (remain 0m 19s) Loss: 1.6310
# EVAL: [560/866] Elapsed 0m 34s (remain 0m 18s) Loss: 1.6308
# EVAL: [580/866] Elapsed 0m 35s (remain 0m 17s) Loss: 1.6320
# EVAL: [600/866] Elapsed 0m 36s (remain 0m 16s) Loss: 1.6306
# EVAL: [620/866] Elapsed 0m 37s (remain 0m 14s) Loss: 1.6312
# EVAL: [640/866] Elapsed 0m 39s (remain 0m 13s) Loss: 1.6321
# EVAL: [660/866] Elapsed 0m 40s (remain 0m 12s) Loss: 1.6319
# EVAL: [680/866] Elapsed 0m 41s (remain 0m 11s) Loss: 1.6324
# EVAL: [700/866] Elapsed 0m 42s (remain 0m 10s) Loss: 1.6311
# EVAL: [720/866] Elapsed 0m 43s (remain 0m 8s) Loss: 1.6310
# EVAL: [740/866] Elapsed 0m 45s (remain 0m 7s) Loss: 1.6315
# EVAL: [760/866] Elapsed 0m 46s (remain 0m 6s) Loss: 1.6316
# EVAL: [780/866] Elapsed 0m 47s (remain 0m 5s) Loss: 1.6320
# EVAL: [800/866] Elapsed 0m 48s (remain 0m 3s) Loss: 1.6318
# EVAL: [820/866] Elapsed 0m 50s (remain 0m 2s) Loss: 1.6317
# EVAL: [840/866] Elapsed 0m 51s (remain 0m 1s) Loss: 1.6313
# EVAL: [860/866] Elapsed 0m 52s (remain 0m 0s) Loss: 1.6307
# Epoch 2 - avg_train_loss: 1.6290  avg_val_loss: 1.6310  time: 804s
# Epoch 2 - Score: 0.0598
# EVAL: [865/866] Elapsed 0m 52s (remain 0m 0s) Loss: 1.6310
# ========== Fold: 4 result ==========
# Score: 0.0598
# ========== CV ==========
# Score: -0.0048
